# %% [markdown]
# # Introduction
#
# $\newcommand{\G}{\mathcal{G}}$
# $\newcommand{\V}{\mathcal{V}}$
# $\newcommand{\E}{\mathcal{E}}$
# $\newcommand{\R}{\mathbb{R}}$
#
# This notebook shows how to apply our graph ConvNet ([paper] & [code]), or any other, to your structured or unstructured data. For this example, we assume that we have $n$ samples $x_i \in \R^{d_x}$ arranged in a data matrix $$X = [x_1, ..., x_n]^T \in \R^{n \times d_x}.$$ Each sample $x_i$ is associated with a vector $y_i \in \R^{d_y}$ for a regression task or a label $y_i \in \{0,\ldots,C\}$ for a classification task.
#
# [paper]: https://arxiv.org/abs/1606.09375
# [code]:  https://github.com/mdeff/cnn_graph
#
# From there, we'll structure our data with a graph $\G = (\V, \E, A)$ where $\V$ is the set of $d_x = |\V|$ vertices, $\E$ is the set of edges and $A \in \R^{d_x \times d_x}$ is the adjacency matrix. That matrix represents the weight of each edge, i.e. $A_{i,j}$ is the weight of the edge connecting $v_i \in \V$ to $v_j \in \V$. The weights of that feature graph thus represent pairwise relationships between features $i$ and $j$. We call that regime **signal classification / regression**, as the samples $x_i$ to be classified or regressed are graph signals.
#
# Other modelling possibilities include:
# 1. Using a data graph, i.e. an adjacency matrix $A \in \R^{n \times n}$ which represents pairwise relationships between samples $x_i \in \R^{d_x}$. The problem is here to predict a graph signal $y \in \R^{n \times d_y}$ given a graph characterized by $A$ and some graph signals $X \in \R^{n \times d_x}$. We call that regime **node classification / regression**, as we classify or regress nodes instead of signals.
# 2. Another problem of interest is whole graph classification, with or without signals on top. We'll call that third regime **graph classification / regression**. The problem here is to classify or regress a whole graph $A_i \in \R^{n \times n}$ (with or without an associated data matrix $X_i \in \R^{n \times d_x}$) into $y_i \in \R^{d_y}$. In case we have no signal, we can use a constant vector $X_i = 1_n$ of size $n$.

# %%
from lib import models, graph, coarsening, utils
import numpy as np
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline
import sys  
from sklearn import preprocessing
from sklearn import *
# Out:
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/lda.py:6: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/learning_curve.py:23: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/qda.py:6: DeprecationWarning: qda.QDA has been moved to discriminant_analysis.QuadraticDiscriminantAnalysis in 0.17 and will be removed in 0.19.
#   "in 0.17 and will be removed in 0.19.", DeprecationWarning)

# %% [markdown]
# # 1 Data
#
# For the purpose of the demo, let's create a random data matrix $X \in \R^{n \times d_x}$ and somehow infer a label $y_i = f(x_i)$.

# %%
####DX Classification
# exp_setup_path = '/projects/nikhil/ADNI_prediction/input_datasets/exp_data/CV_Exp6_ADNI2_ADAS13.pkl'

# X_raw = exp_setup['X']
# y_raw = exp_setup['y']
# y_dx_raw = np.array(exp_setup['y_dx'])
# print(np.sum(y_dx_raw=='CN'),np.sum(y_dx_raw=='AD'),np.sum(y_dx_raw=='MCI'))

# le = preprocessing.LabelEncoder()
# le.fit(y_dx_raw)
# y_int = le.transform(y_dx_raw) 
# print(np.sum(y_int==0),np.sum(y_int==1),np.sum(y_int==2))

# idx = np.arange(n)
# np.random.shuffle(idx)

# X_CN = X_raw[y_int==1,:]
# X_AD = X_raw[y_int==0,:]
# X  = np.vstack((X_CN[:123,:],X_AD))
# y = np.concatenate((np.ones(123),np.zeros(123)))
# X = X[idx,2:]
# y = y[idx]


# d = 78    # Dimensionality.
# n = 123+123 #Number of samples.(123:AD(dx_int=0), 256:CN(dx_int=1))
# c = 5      # Number of feature communities.

####Traj Classification
exp_setup_path = '/projects/nikhil/ADNI_prediction/input_datasets/longitudinal_trajectories/exp_setup/CV_paired_long_data.pkl'
timepoint = 'L_R' #'L', 'R', 'L_R'
feat_offset = 18

with open(exp_setup_path, 'rb') as f:
    exp_setup = pickle.load(f, encoding='latin') 

if timepoint == 'L':
    X_train = exp_setup['X_L_train'][:,feat_offset:]
    X_test = exp_setup['X_L_test'][:,feat_offset:]
elif timepoint == 'R':
    X_train = exp_setup['X_R_train'][:,feat_offset:]
    X_test = exp_setup['X_R_test'][:,feat_offset:]
elif timepoint == 'L_R':
    X_train = np.hstack((exp_setup['X_L_train'][:,feat_offset:],exp_setup['X_R_train'][:,feat_offset:]))
    X_test = np.hstack((exp_setup['X_L_test'][:,feat_offset:],exp_setup['X_R_test'][:,feat_offset:]))

y_train = exp_setup['y_train']
y_test = exp_setup['y_test']        

X = X_train #np.vstack((X_train,X_test))
y = y_train #np.concatenate((y_train,y_test))

d = X.shape[1]  #Dimensionality.
n = X.shape[0] #Number of samples.

print('Data shapes and label distribution')
print(X.shape, y.shape)
print(np.sum(y==1)/len(y),np.sum(y==0)/len(y))

#shuffle data
idx = np.arange(n)
np.random.shuffle(idx)
X = X[idx,:]
y = y[idx]


# # Data matrix, structured in communities (feature-wise).
# X = np.random.normal(0, 1, (n, d)).astype(np.float32)
# X += np.linspace(0, 1, c).repeat(d // c)

# # Noisy non-linear target.
# w = np.random.normal(0, .02, d)
# t = X.dot(w) + np.random.normal(0, .001, n)
# t = np.tanh(t)
# plt.figure(figsize=(15, 5))
# plt.plot(t, '.')

# # Classification.
# y = np.ones(t.shape, dtype=np.uint8)
# y[t > t.mean() + 0.4 * t.std()] = 0
# y[t < t.mean() - 0.4 * t.std()] = 2
# print('Class imbalance: ', np.unique(y, return_counts=True)[1])

n_train = 768 #int(0.9*n)
#n_val = int(0.1*n)

X_train = X[:n_train]
X_val   = X[n_train:]
y_train = y[:n_train]
y_val   = y[n_train:]


# X_test  = X[n_train+n_val:]
# y_test  = y[n_train+n_val:]

print('train/test shapes and label distribution')
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
print(np.sum(y_train==1)/len(y_train),np.sum(y_train==0)/len(y_train),
     np.sum(y_val==1)/len(y_val),np.sum(y_val==0)/len(y_val),
     np.sum(y_test==1)/len(y_test),np.sum(y_test==0)/len(y_test))

# Sanity check with permuted labels should yield performance = random chance
#np.random.shuffle(y_train)
# Out:
# Data shapes and label distribution
# (846, 156) (846,)
# 0.517730496454 0.482269503546
# train/test shapes and label distribution
# (768, 156) (768,) (78, 156) (78,) (90, 156) (90,)
# 0.522135416667 0.477864583333 0.474358974359 0.525641025641 0.533333333333 0.466666666667

# %% [markdown]
# # 2 Graph
#
# The second thing we need is a **graph between features**, i.e. an adjacency matrix $A \in \mathbb{R}^{d_x \times d_x}$.
# Structuring data with graphs is very flexible: it can accomodate both structured and unstructured data.
# 1. **Structured data**.
#     1. The data is structured by an Euclidean domain, e.g. $x_i$ represents an image, a sound or a video. We can use a classical ConvNet with 1D, 2D or 3D convolutions or a graph ConvNet with a line or grid graph (however losing the orientation).
#     2. The data is structured by a graph, e.g. the data lies on a transportation, energy, brain or social network.
# 2. **Unstructured data**. We could use a fully connected network, but the learning and computational complexities are gonna be large. An alternative is to construct a sparse similarity graph between features (or between samples) and use a graph ConvNet, effectively structuring the data and drastically reducing the number of parameters through weight sharing. As for classical ConvNets, the number of parameters are independent of the input size.
#
# There are many ways, supervised or unsupervised, to construct a graph given some data. And better the graph, better the performance ! For this example we'll define the adjacency matrix as a simple similarity measure between features. Below are the choices one has to make when constructing such a graph.
# 1. The distance function. We'll use the Euclidean distance $d_{ij} = \|x_i - x_j\|_2$.
# 2. The kernel. We'll use the Gaussian kernel $a_{ij} = \exp(d_{ij}^2 / \sigma^2)$.
# 3. The type of graph. We'll use a $k$ nearest neigbors (kNN) graph.

# %%
#dist, idx = graph.distance_scipy_spatial(X_train.T, k=10, metric='correlation')
dist, idx = graph.distance_scipy_spatial(X_train.T, k=5, metric='correlation')
A = graph.adjacency(dist, idx).astype(np.float32)

assert A.shape == (d, d)
print('d = |V| = {}, k|V| < |E| = {}'.format(d, A.nnz))

print(np.max(A),np.min(A))
plt.spy(A, markersize=2, color='red');

# Set off-diagonal to 1 enforcing connections between timepoints.
rows, cols = np.indices((d,d))

for k in [-int(d/2),int(d/2)]:
    row_vals = np.diag(rows, k=k)
    col_vals = np.diag(cols, k=k)
    A[row_vals, col_vals]=1
    
plt.spy(A, markersize=2, color='red');
# Out:
# d = |V| = 156, k|V| < |E| = 1002
# 0.918301 0.0
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/scipy/sparse/compressed.py:730: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)

# %% [markdown]
# To be able to pool graph signals, we need first to coarsen the graph, i.e. to find which vertices to group together. At the end we'll have multiple graphs, like a pyramid, each at one level of resolution. The finest graph is where the input data lies, the coarsest graph is where the data at the output of the graph convolutional layers lie. That data, of reduced spatial dimensionality, can then be fed to a fully connected layer.
#
# The parameter here is the number of times to coarsen the graph. Each coarsening approximately reduces the size of the graph by a factor two. Thus if you want a pooling of size 4 in the first layer followed by a pooling of size 2 in the second, you'll need to coarsen $\log_2(4+2) = 3$ times.
#
# After coarsening we rearrange the vertices (and add fake vertices) such that pooling a graph signal is analog to pooling a 1D signal. See the [paper] for details.
#
# [paper]: https://arxiv.org/abs/1606.09375

# %%
graphs, perm = coarsening.coarsen(A, levels=4, self_connections=False)

print(X_train.shape)
X_train = coarsening.perm_data(X_train, perm)
X_val = coarsening.perm_data(X_val, perm)
X_test = coarsening.perm_data(X_test, perm)
print(X_train.shape)
# Out:
# Layer 0: M_0 = |V| = 176 nodes (20 added),|E| = 555 edges
# Layer 1: M_1 = |V| = 88 nodes (10 added),|E| = 273 edges
# Layer 2: M_2 = |V| = 44 nodes (3 added),|E| = 158 edges
# Layer 3: M_3 = |V| = 22 nodes (1 added),|E| = 86 edges
# Layer 4: M_4 = |V| = 11 nodes (0 added),|E| = 35 edges
# (768, 156)
# (768, 176)

# %%
#Plot coarsened graphs
fig, ax1 = plt.subplots(figsize=(15, 5))
for g, A in enumerate(graphs):
    plt.subplot(1,len(graphs),g+1)
    plt.spy(A, markersize=2, color='red')

# %% [markdown]
# We finally need to compute the graph Laplacian $L$ for each of our graphs (the original and the coarsened versions), defined by their adjacency matrices $A$. The sole parameter here is the type of Laplacian, e.g. the combinatorial Laplacian, the normalized Laplacian or the random walk Laplacian.

# %%
L = [graph.laplacian(A, normalized=True) for A in graphs]
graph.plot_spectrum(L)

# %% [markdown]
# # 3 Graph ConvNet
#
# Here we apply the graph convolutional neural network to signals lying on graphs. After designing the architecture and setting the hyper-parameters, the model takes as inputs the data matrix $X$, the target $y$ and a list of graph Laplacians $L$, one per coarsening level.
#
# The data, architecture and hyper-parameters are absolutely *not engineered to showcase performance*. Its sole purpose is to illustrate usage and functionality.

# %%
params = dict()
params['dir_name']       = 'demo'
params['num_epochs']     = 1000
params['batch_size']     = 128
params['eval_frequency'] = 100

# Building blocks.
params['filter']         = 'chebyshev5'
params['brelu']          = 'b1relu'
params['pool']           = 'apool1'

# Number of classes.
C = y.max() + 1
assert C == np.unique(y).size
print(C)

# Architecture.
params['F']              = [16,16]  # Number of graph convolutional filters.
params['K']              = [5,5]  # Polynomial orders.
params['p']              = [4,4]    # Pooling sizes.
params['M']              = [16, C]  # Output dimensionality of fully connected layers.

# Optimization.
params['regularization'] = 1e-4
params['dropout']        = 1
params['learning_rate']  = 4e-3
params['decay_rate']     = 0.99
params['momentum']       = 0.8
params['decay_steps']    = n_train #/ params['batch_size']
# Out:
# 2

# %%
model = models.cgcnn(L, **params)
accuracy, loss, t_step = model.fit(X_train, y_train, X_test, y_test)

# Grid search doesn't work
#parameterGrid = {"learning_rate": [1e-3, 1e-4], "F": [[16,16],[32,32]]}
#utils.grid_search(params, parameterGrid, X_train, y_train, X_val, y_val, X_test, y_test, model)
# Out:
# NN architecture
#   input: M_0 = 176
#   layer 1: cgconv1
#     representation: M_0 * F_1 / p_1 = 176 * 16 / 4 = 704
#     weights: F_0 * F_1 * K_1 = 1 * 16 * 5 = 80
#     biases: F_1 = 16
#   layer 2: cgconv2
#     representation: M_1 * F_2 / p_2 = 44 * 16 / 4 = 176
#     weights: F_1 * F_2 * K_2 = 16 * 16 * 5 = 1280
#     biases: F_2 = 16
#   layer 3: fc1
#     representation: M_3 = 16
#     weights: M_2 * M_3 = 176 * 16 = 2816
#     biases: M_3 = 16
#   layer 4: logits (softmax)
#     representation: M_4 = 2
#     weights: M_3 * M_4 = 16 * 2 = 32
#     biases: M_4 = 2
# step 100 / 6000 (epoch 16.67 / 1000):
#   learning_rate = 4.00e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.01e+00
#   time: 2s (wall 1s)
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# step 200 / 6000 (epoch 33.33 / 1000):
#   learning_rate = 4.00e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.01e+00
#   time: 5s (wall 3s)
# step 300 / 6000 (epoch 50.00 / 1000):
#   learning_rate = 4.00e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.01e+00
#   time: 7s (wall 4s)
# step 400 / 6000 (epoch 66.67 / 1000):
#   learning_rate = 4.00e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.01e+00
#   time: 10s (wall 5s)
# step 500 / 6000 (epoch 83.33 / 1000):
#   learning_rate = 4.00e-03, loss_average = 6.94e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.01e+00
#   time: 12s (wall 7s)
# step 600 / 6000 (epoch 100.00 / 1000):
#   learning_rate = 4.00e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.00e+00
#   time: 14s (wall 8s)
# step 700 / 6000 (epoch 116.67 / 1000):
#   learning_rate = 4.00e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.00e+00
#   time: 17s (wall 9s)
# step 800 / 6000 (epoch 133.33 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.00e+00
#   time: 19s (wall 11s)
# step 900 / 6000 (epoch 150.00 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.00e+00
#   time: 21s (wall 12s)
# step 1000 / 6000 (epoch 166.67 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.00e+00
#   time: 24s (wall 13s)
# step 1100 / 6000 (epoch 183.33 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 1.00e+00
#   time: 26s (wall 14s)
# step 1200 / 6000 (epoch 200.00 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.99e-01
#   time: 28s (wall 16s)
# step 1300 / 6000 (epoch 216.67 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.97e-01
#   time: 31s (wall 17s)
# step 1400 / 6000 (epoch 233.33 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.96e-01
#   time: 33s (wall 18s)
# step 1500 / 6000 (epoch 250.00 / 1000):
#   learning_rate = 3.96e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.95e-01
#   time: 35s (wall 19s)
# step 1600 / 6000 (epoch 266.67 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.94e-01
#   time: 38s (wall 21s)
# step 1700 / 6000 (epoch 283.33 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.94e-01
#   time: 40s (wall 22s)
# step 1800 / 6000 (epoch 300.00 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.92e-01
#   time: 42s (wall 23s)
# step 1900 / 6000 (epoch 316.67 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.91e-01
#   time: 45s (wall 25s)
# step 2000 / 6000 (epoch 333.33 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.90e-01
#   time: 47s (wall 26s)
# step 2100 / 6000 (epoch 350.00 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.89e-01
#   time: 49s (wall 27s)
# step 2200 / 6000 (epoch 366.67 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.87e-01
#   time: 52s (wall 29s)
# step 2300 / 6000 (epoch 383.33 / 1000):
#   learning_rate = 3.92e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.86e-01
#   time: 54s (wall 30s)
# step 2400 / 6000 (epoch 400.00 / 1000):
#   learning_rate = 3.88e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.85e-01
#   time: 56s (wall 31s)
# step 2500 / 6000 (epoch 416.67 / 1000):
#   learning_rate = 3.88e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.84e-01
#   time: 59s (wall 32s)
# step 2600 / 6000 (epoch 433.33 / 1000):
#   learning_rate = 3.88e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.82e-01
#   time: 61s (wall 34s)
# step 2700 / 6000 (epoch 450.00 / 1000):
#   learning_rate = 3.88e-03, loss_average = 6.93e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.81e-01
#   time: 63s (wall 35s)
# step 2800 / 6000 (epoch 466.67 / 1000):
#   learning_rate = 3.88e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.80e-01
#   time: 66s (wall 36s)
# step 2900 / 6000 (epoch 483.33 / 1000):
#   learning_rate = 3.88e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.78e-01
#   time: 68s (wall 37s)
# step 3000 / 6000 (epoch 500.00 / 1000):
#   learning_rate = 3.88e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.77e-01
#   time: 70s (wall 39s)
# step 3100 / 6000 (epoch 516.67 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.74e-01
#   time: 73s (wall 40s)
# step 3200 / 6000 (epoch 533.33 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.73e-01
#   time: 75s (wall 41s)
# step 3300 / 6000 (epoch 550.00 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.71e-01
#   time: 78s (wall 43s)
# step 3400 / 6000 (epoch 566.67 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.70e-01
#   time: 80s (wall 44s)
# step 3500 / 6000 (epoch 583.33 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.67e-01
#   time: 82s (wall 45s)
# step 3600 / 6000 (epoch 600.00 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.65e-01
#   time: 85s (wall 46s)
# step 3700 / 6000 (epoch 616.67 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.63e-01
#   time: 87s (wall 48s)
# step 3800 / 6000 (epoch 633.33 / 1000):
#   learning_rate = 3.84e-03, loss_average = 6.92e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.61e-01
#   time: 89s (wall 49s)
# step 3900 / 6000 (epoch 650.00 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.58e-01
#   time: 92s (wall 51s)
# step 4000 / 6000 (epoch 666.67 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.55e-01
#   time: 94s (wall 52s)
# step 4100 / 6000 (epoch 683.33 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.53e-01
#   time: 97s (wall 53s)
# step 4200 / 6000 (epoch 700.00 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.51e-01
#   time: 99s (wall 54s)
# step 4300 / 6000 (epoch 716.67 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.48e-01
#   time: 101s (wall 56s)
# step 4400 / 6000 (epoch 733.33 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.45e-01
#   time: 104s (wall 57s)
# step 4500 / 6000 (epoch 750.00 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.90e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.42e-01
#   time: 106s (wall 58s)
# step 4600 / 6000 (epoch 766.67 / 1000):
#   learning_rate = 3.80e-03, loss_average = 6.91e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.39e-01
#   time: 108s (wall 59s)
# step 4700 / 6000 (epoch 783.33 / 1000):
#   learning_rate = 3.77e-03, loss_average = 6.90e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.37e-01
#   time: 111s (wall 61s)
# step 4800 / 6000 (epoch 800.00 / 1000):
#   learning_rate = 3.77e-03, loss_average = 6.90e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.33e-01
#   time: 113s (wall 62s)
# step 4900 / 6000 (epoch 816.67 / 1000):
#   learning_rate = 3.77e-03, loss_average = 6.90e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.30e-01
#   time: 115s (wall 63s)
# step 5000 / 6000 (epoch 833.33 / 1000):
#   learning_rate = 3.77e-03, loss_average = 6.89e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.27e-01
#   time: 118s (wall 64s)
# step 5100 / 6000 (epoch 850.00 / 1000):
#   learning_rate = 3.77e-03, loss_average = 6.90e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.23e-01
#   time: 120s (wall 66s)
# step 5200 / 6000 (epoch 866.67 / 1000):
#   learning_rate = 3.77e-03, loss_average = 6.90e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.19e-01
#   time: 122s (wall 67s)
# step 5300 / 6000 (epoch 883.33 / 1000):
#   learning_rate = 3.77e-03, loss_average = 6.89e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.16e-01
#   time: 125s (wall 68s)
# step 5400 / 6000 (epoch 900.00 / 1000):
#   learning_rate = 3.73e-03, loss_average = 6.89e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.11e-01
#   time: 127s (wall 70s)
# step 5500 / 6000 (epoch 916.67 / 1000):
#   learning_rate = 3.73e-03, loss_average = 6.90e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.07e-01
#   time: 129s (wall 71s)
# step 5600 / 6000 (epoch 933.33 / 1000):
#   learning_rate = 3.73e-03, loss_average = 6.88e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.02e-01
#   time: 132s (wall 72s)
# step 5700 / 6000 (epoch 950.00 / 1000):
#   learning_rate = 3.73e-03, loss_average = 6.88e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 8.97e-01
#   time: 134s (wall 74s)
# step 5800 / 6000 (epoch 966.67 / 1000):
#   learning_rate = 3.73e-03, loss_average = 6.88e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 8.93e-01
#   time: 136s (wall 75s)
# step 5900 / 6000 (epoch 983.33 / 1000):
#   learning_rate = 3.73e-03, loss_average = 6.88e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 8.88e-01
#   time: 139s (wall 76s)
# step 6000 / 6000 (epoch 1000.00 / 1000):
#   learning_rate = 3.73e-03, loss_average = 6.87e-01
#   validation accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 8.83e-01
#   time: 141s (wall 77s)
# validation accuracy: peak = 53.33, mean = 53.33

# %% [markdown]
# # 4 Evaluation
#
# We often want to monitor:
# 1. The convergence, i.e. the training loss and the classification accuracy on the validation set.
# 2. The performance, i.e. the classification accuracy on the testing set (to be compared with the training set accuracy to spot overfitting).
#
# The `model_perf` class in [utils.py](utils.py) can be used to compactly evaluate multiple models.

# %%
fig, ax1 = plt.subplots(figsize=(15, 5))
ax1.plot(accuracy, 'b.-')
ax1.set_ylabel('validation accuracy', color='b')
ax2 = ax1.twinx()
ax2.plot(loss, 'g.-')
ax2.set_ylabel('validation loss', color='g')
plt.show()

# %%
print('Time per step: {:.2f} ms'.format(t_step*1000))
# Out:
# Time per step: 13.57 ms

# %%
res = model.evaluate(X_train, y_train)
print('train:', res[0])
res = model.evaluate(X_val, y_val)
print('val:', res[0])
res = model.evaluate(X_test, y_test)
print('test:', res[0])
# Out:
# train: accuracy: 52.86 (406 / 768), f1 (weighted): 37.79, loss: 6.91e-01
# time: 0s (wall 0s)
# val: accuracy: 52.56 (41 / 78), f1 (weighted): 36.22, loss: 1.07e+00
# time: 0s (wall 0s)
# test: accuracy: 53.33 (48 / 90), f1 (weighted): 37.10, loss: 9.38e-01
# time: 0s (wall 0s)
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Print results for each pair of timepoints (bl-m06,bl-m12,bl-m24,m06-m12,m06-m24,m12-m24)
print(exp_setup['tp1_test'].shape)
print(exp_setup['X_L_test'].shape)
print(X_test.shape)
tp1_test = exp_setup['tp1_test']
tp_batch = 15
for tp_idx in range(0,90,tp_batch):    
    print(tp_idx, tp_idx+tp_batch, X_test[tp_idx:tp_idx+tp_batch,:].shape)
    res = model.evaluate(X_test[tp_idx:tp_idx+tp_batch,:], y_test[tp_idx:tp_idx+tp_batch])
    print(res[0])
# Out:
# (90,)
# (90, 96)
# (90, 160)
# 0 15 (15, 160)
# /projects/nikhil/ADNI_prediction/code/conda_envs/tensorflow_gpu/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# accuracy: 53.33 (8 / 15), f1 (weighted): 37.10, loss: 5.13e+00
# time: 0s (wall 0s)
# 15 30 (15, 160)
# accuracy: 53.33 (8 / 15), f1 (weighted): 37.10, loss: 5.13e+00
# time: 0s (wall 0s)
# 30 45 (15, 160)
# accuracy: 53.33 (8 / 15), f1 (weighted): 37.10, loss: 5.13e+00
# time: 0s (wall 0s)
# 45 60 (15, 160)
# accuracy: 53.33 (8 / 15), f1 (weighted): 37.10, loss: 5.13e+00
# time: 0s (wall 0s)
# 60 75 (15, 160)
# accuracy: 53.33 (8 / 15), f1 (weighted): 37.10, loss: 5.13e+00
# time: 0s (wall 0s)
# 75 90 (15, 160)
# accuracy: 53.33 (8 / 15), f1 (weighted): 37.10, loss: 5.13e+00
# time: 0s (wall 0s)

# %%
# Get model weights and biases
var_name_weight_dict = {}
for i in (model.graph.get_collection('variables')):
    var_name = i.name.split(':')[0] 
    var_weights = model.get_var(var_name)
    print(var_name, var_weights.shape)
    var_name_weight_dict[var_name] = var_weights
# Out:
# conv1/weights (10, 20)
# conv1/bias (1, 1, 20)
# conv2/weights (40, 10)
# conv2/bias (1, 1, 10)
# fc1/weights (400, 8)
# fc1/bias (8,)
# logits/weights (8, 2)
# logits/bias (2,)
# loss/averages/loss/cross_entropy/Mean/ExponentialMovingAverage ()
# loss/averages/loss/regularization/mul/ExponentialMovingAverage ()
# loss/averages/loss/add/ExponentialMovingAverage ()
# training/global_step ()
# training/conv1/weights/Momentum (10, 20)
# training/conv1/bias/Momentum (1, 1, 20)
# training/conv2/weights/Momentum (40, 10)
# training/conv2/bias/Momentum (1, 1, 10)
# training/fc1/weights/Momentum (400, 8)
# training/fc1/bias/Momentum (8,)
# training/logits/weights/Momentum (8, 2)
# training/logits/bias/Momentum (2,)

# %%
conv1_W = model.get_var('conv1/weights')
conv2_W = model.get_var('conv2/weights')
fc1_W = model.get_var('fc1/weights')
#fc2_W = model.get_var('fc2/weights')
print(conv1_W.shape,conv2_W.shape,fc1_W.shape,fc2_W.shape)
# Out:
# (10, 20) (40, 10) (400, 8) (4, 4)

# %%
fig, ax1 = plt.subplots(figsize=(25, 5))
plt.imshow(fc2_W.T, interpolation='nearest')
plt.colorbar()

# %%
#model.graph.get_all_collection_keys()
# Out:
# 'conv1/weights:0'

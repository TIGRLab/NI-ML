# %% [markdown]
# # Prognositc (trajectory prediction) performance of baseline ML models on ADNI2 longitudinal data
#
# * **Objectives:**
#     1. Predict Trajectory classes based on structural features
#     2. Predict Trajectory classes based on structural features + baseline clinical score + demographics
#
#
# * **Input modalities:**
#     1. Coritcal thickness (CT)
#     2. Hippocampal subfield volumes (HC)
#
#
# * **Models:**
#     1. Logistic regression (Lasso)
#     2. SVM
#     3. Random Forest
#
#
# * **Code organization:**
#     1. Stage 1:
#         1. Import raw data, and setup CV folds based on choice of input features
#         2. Save this experimental setup to disk
#
#     2. Stage 2:
#         1. Train and test ML models over k-fold setup (Parallelized implmentation)
#         2. Plot and save performance results

# %%
# Basic Imports
import numpy as np
import pandas as pd
from scipy import stats
import pickle
import re
import collections
#import tables as tb
from math import isnan
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import KFold

# %matplotlib inline
#plt.rcParams['figure.figsize'] = (15, 10)
#plt.style.use('ggplot')
# Out:
# /projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Some Defs
def load_data(data_path, input_node, preproc):
    data = tb.open_file(data_path, 'r')
    X_raw = data.get_node('/' + input_node)[:]
    if preproc == 'scale':
        X = preprocessing.scale(X_raw)
    elif preproc == 'norm_max':
        X = preprocessing.normalize(X_raw, norm='max')
    elif preproc == 'norm_l2':
        X = preprocessing.normalize(X_raw, norm='l2')
    else:
        X = X_raw
    data.close()
    return X

def pickleIt(my_data,save_path):
    f = open(save_path, 'wb')
    pickle.dump(my_data, f)
    f.close()

#Outer Fold Computation (need the imports inside def if you want to parallelize!)
def computeOuterFold(train_X, train_y, valid_X, valid_y, Sub_train, Sub_valid, model_clf, hyper_params, output_type, model_type):    
    import collections
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import Lasso
    from sklearn.svm import SVR
    from sklearn.ensemble import RandomForestRegressor
    from sklearn import grid_search
    import datetime
    import time
    import collections
    from scipy.stats import mode
    from sklearn.metrics import mean_squared_error as mse
    from sklearn.metrics import mean_absolute_error as mae
    from scipy import stats
    import numpy as np
    
    print 'Starting Outerfold computation'
    
    hp_dict = collections.defaultdict(list) #store best hyper-parameters for each fold
    inner_loop = True
    if inner_loop:     
        print 'Starting InnerFold computation'        
        clf = innerCVLoop(model_clf,hyper_params,train_X, train_y)
        for hp in hyper_params:
            hp_dict[hp].append(clf.best_estimator_.get_params()[hp])
            
        print 'Ending InnerFold computation'

    else:
        clf = model_clf
        clf.fit(fold_X,fold_y)
        
    if output_type == 'classify':
        pred_y = clf.predict(valid_X) #Specific label value
        pred_y_prob = clf.predict_proba(valid_X) #Label probabilty (used for ROC)

        #feature imp (issue with the innerCVLoop)
        if model_type == 'RFC':
            feat_imp = clf.best_estimator_.feature_importances_
        elif model_type == 'LR_L1':
            feat_imp = clf.best_estimator_.coef_ 
        else: 
            print "Unknown model for computing feature importance. Setting it to zeros"
            feat_imp = np.zeros(len(pred_y))

        print 'Ending OuterFold computation'

        return_dict = {'actual_fold_scores':valid_y, 'predicted_fold_prob':pred_y_prob, 'predicted_fold_score': pred_y, 
                'hp_dict':hp_dict, 'feat_imp': feat_imp,'Sub_train':Sub_train,'Sub_valid':Sub_valid}
    
    else: 
        print 'unknown output_type'

    print 'Ending OuterFold computation'
    
    return return_dict

#Inner Fold Computation (need the imports inside def if you want to parallelize!)
def innerCVLoop(model_clf,hyper_params,fold_X, fold_y):
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import Lasso
    from sklearn.svm import SVR
    from sklearn.ensemble import RandomForestRegressor
    from sklearn import grid_search
    clf = grid_search.GridSearchCV(model_clf, hyper_params,cv=3,verbose=0)
    clf.fit(fold_X, fold_y)   
    return clf

def autolabel(rects,_ax):
    for rect in rects:
        height = rect.get_height()
        _ax.text(rect.get_x() + rect.get_width()/2., 1.1*height,
                '{:03.2f}'.format(height),
                ha='center',            # vertical alignment
                va='bottom',             # horizontal alignment
                fontsize = 35)

# %% [markdown]
# ## Stage 1

# %%
# Data imports
baseline_dir = '/projects/nbhagwat/Traj_prediction/ADNI/exp_setup/'

#Exp series:
#101:bl, 102:var_tp
#1xx: All subjects, 2xx:CN and AD excluded
#301:bl (traj_xy),302:var_tp (traj_xy)
#501:bl, 502:var_tp revised traj_labels
my_name = 'Exp_602'
cohort = 'ALL_ADNI'
tp_name = 'var_tp' #bl or var_tp
clinical_scale = 'ADAS13' #For trajectory definitions
mci_only = False

input_csv = '{}_{}.csv'.format(cohort,tp_name)
in_data = pd.read_csv(baseline_dir + input_csv)

#Exclude certain subjects (based on DX_bl usually)
if mci_only:
    print 'excluding CN and AD subjects'
    in_data = in_data[~in_data['DX_bl'].isin(['CN','AD'])]

traj_csv = 'ADNI_trajectory_labels_3class_{}_3cstp_from_m72_autoselect.csv'.format(clinical_scale)
traj_data = pd.read_csv(baseline_dir + traj_csv)

exp_name = '{}_{}_traj_{}_tp_{}'.format(my_name,cohort,clinical_scale,tp_name)

print 'exp_name: {}'.format(exp_name)
print 'subx, MR+CS:{}, traj: {}'.format(len(in_data),len(traj_data))

#Merge MR + traj data
input_traj_merge_data = pd.merge(in_data,traj_data[['PTID','traj','ORIGPROT']],on='PTID',how='inner')
print 'merge subx: {}'.format(len(input_traj_merge_data))

ct_cols = list(in_data.columns[pd.Series(in_data.columns).str.contains('CT')])
demo_cols = ['AGE','APOE4']
# Out:
# exp_name: Exp_602_ALL_ADNI_traj_ADAS13_tp_var_tp
# subx, MR+CS:1176, traj: 1472
# merge subx: 1115

# %%
df = input_traj_merge_data
df['strata'] = np.zeros(len(df))
df.loc[(df['traj']==0)&(df['ORIGPROT']=='ADNI1'), 'strata'] = 0
df.loc[(df['traj']==0)&(df['ORIGPROT']=='ADNIGO'), 'strata'] = 1
df.loc[(df['traj']==0)&(df['ORIGPROT']=='ADNI2'), 'strata'] = 2
df.loc[(df['traj']==1)&(df['ORIGPROT']=='ADNI1'), 'strata'] = 3
df.loc[(df['traj']==1)&(df['ORIGPROT']=='ADNIGO'), 'strata'] = 4
df.loc[(df['traj']==1)&(df['ORIGPROT']=='ADNI2'), 'strata'] = 5
df.loc[(df['traj']==2)&(df['ORIGPROT']=='ADNI1'), 'strata'] = 6
df.loc[(df['traj']==2)&(df['ORIGPROT']=='ADNIGO'), 'strata'] = 7
df.loc[(df['traj']==2)&(df['ORIGPROT']=='ADNI2'), 'strata'] = 8

# df.loc[(df['traj_xy']==0)&(df['ORIGPROT']=='ADNI1'), 'strata'] = 1
# df.loc[(df['traj_xy']==1)&(df['ORIGPROT']=='ADNI1'), 'strata'] = 2
# df.loc[(df['traj_xy']==2)&(df['ORIGPROT']=='ADNI1'), 'strata'] = 2
# df.loc[(df['traj_xy']==3)&(df['ORIGPROT']=='ADNI1'), 'strata'] = 3
# df.loc[(df['traj_xy']==0)&(df['ORIGPROT']=='ADNI2'), 'strata'] = 4
# df.loc[(df['traj_xy']==1)&(df['ORIGPROT']=='ADNI2'), 'strata'] = 5
# df.loc[(df['traj_xy']==2)&(df['ORIGPROT']=='ADNI2'), 'strata'] = 6
# df.loc[(df['traj_xy']==3)&(df['ORIGPROT']=='ADNI2'), 'strata'] = 7
# df.loc[(df['traj_xy']==0)&(df['ORIGPROT']=='ADNIGO'), 'strata'] = 8
# df.loc[(df['traj_xy']==1)&(df['ORIGPROT']=='ADNIGO'), 'strata'] = 9
# df.loc[(df['traj_xy']==2)&(df['ORIGPROT']=='ADNIGO'), 'strata'] = 10
# df.loc[(df['traj_xy']==3)&(df['ORIGPROT']=='ADNIGO'), 'strata'] = 11

# %%
#Stratified K-fold for the stack
save_experimental_setup = False
X = np.array(input_traj_merge_data[ct_cols].values)
y = np.array(input_traj_merge_data['traj'].values)
strata = df['strata']
sKF = StratifiedKFold(strata, n_folds=10)
for train_index, test_index in sKF:    
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print 'y distribution: train:{},{},{}, test:{},{},{}'.format(np.sum(y_train==0),np.sum(y_train==1),np.sum(y_train==2),
                                                                       np.sum(y_test==0),np.sum(y_test==1),np.sum(y_test==2))
    
save_path = baseline_dir + 'KFolds/' + exp_name + '_sKF.pkl'    
print 'Saving exp_setup to: {}'.format(save_path)
if save_experimental_setup:    
    exp_setup = {'exp_name':exp_name,'df':input_traj_merge_data,'sKF':sKF}
    pickleIt(exp_setup, save_path)
# Out:
# y distribution: train:525,164,310, test:60,20,36
# y distribution: train:525,165,311, test:60,19,35
# y distribution: train:526,165,311, test:59,19,35
# y distribution: train:526,165,311, test:59,19,35
# y distribution: train:526,165,311, test:59,19,35
# y distribution: train:526,166,311, test:59,18,35
# y distribution: train:527,166,312, test:58,18,34
# y distribution: train:528,166,312, test:57,18,34
# y distribution: train:528,167,312, test:57,17,34
# y distribution: train:528,167,313, test:57,17,33
# Saving exp_setup to: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/KFolds/Exp_602_ALL_ADNI_traj_ADAS13_tp_var_tp_sKF.pkl

# %%
X[train_index]
# Out:
# array([[  2.87044221e+00,   2.96010429e+00,   2.98089528e+00, ...,
#          -1.09614546e-02,   5.81728205e-03,  -7.58459561e-03],
#        [  3.13777053e+00,   3.01970120e+00,   3.01972307e+00, ...,
#          -7.37778274e-02,  -3.00325564e-02,  -2.64373051e-02],
#        [  2.56930000e+00,   2.44140000e+00,   2.69950000e+00, ...,
#          -2.09166667e-03,  -5.20000000e-03,   8.50833333e-03],
#        ...,
#        [  3.06330000e+00,   2.83890000e+00,   3.40750000e+00, ...,
#           1.74000000e-02,   2.00000000e-04,   1.05250000e-02],
#        [  2.44750000e+00,   2.58500000e+00,   2.72930000e+00, ...,
#           1.05833333e-03,   1.10666667e-02,   1.43416667e-02],
#        [  2.51469349e+00,   2.36700058e+00,   2.98793482e+00, ...,
#           2.12852418e-02,   2.37808547e-03,  -6.24058625e-03]])

# %% [markdown]
# # Stage 2

# %%
# Configs for K-fold validations (nested)
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn import grid_search
import datetime
import time
import collections
from scipy.stats import mode
from sklearn.metrics import mean_squared_error as mse
from functools import partial #Parallelize!!! 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from scipy import interp
from sklearn.metrics import accuracy_score as acc
import ipyparallel as ipp
from sklearn import preprocessing
from sklearn.cross_validation import KFold
import pickle
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
# from imblearn.over_sampling import RandomOverSampler
# from imblearn.over_sampling import SMOTE
# from imblearn.over_sampling import ADASYN #For treating class imbalance
from functools import partial #Parallelize!!! 
import time
# Out:
# /projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
#Pick model with its configs/hyper-paramsd
def getModel(model_choice,output_type): 
    if output_type == 'regression' :
        if model_choice == 'LR_L1':
            model_clf = Lasso()
            hyper_params = {'alpha':[1, 0.5, 0.1, 0.05, 0.01]} 
            scale_data = True #Scales HC and CT features    
            feat_imp = False   

        elif model_choice == 'SVR':
            model_clf = SVR()
            hyper_params = {'kernel':['linear','rbf'], 'C':[1,10,25]}
            scale_data = True #Scales HC and CT features        
            feat_imp = False

        elif model_choice == 'RFR':
            model_clf = RandomForestRegressor(n_jobs=4)
            hyper_params = {'n_estimators':[10,50,100,200],'min_samples_split':[2,4,8]}    
            scale_data = False    
            feat_imp = False   
        else:
            print "Unknown model choice"
    
    elif output_type =='classify':
        if model_choice == 'LR_L1':
            model_clf = LogisticRegression(penalty='l1',n_jobs=4,class_weight='balanced')
            hyper_params = {'C':[1e-2,5e-2,1e-1,5e-1,1,1e1,1e2]} 
            scale_data = True #Scales features (z-score)            
            shift_labels = False
            feat_imp = False #The learned weights of each variable

        elif model_choice == 'SVC':
            model_clf = SVC(class_weight='balanced',probability=True)
            hyper_params = {'kernel':['linear'], 'C':[1e-2,5e-2,1e-1,5e-1,1,1e1]}
            scale_data = True #Scales HC and CT features            
            shift_labels = True
            feat_imp = False

        elif model_choice == 'RFC':    
            model_clf = RandomForestClassifier(n_jobs=4,class_weight='balanced' )
            hyper_params = {'n_estimators':[10,50,75,100,150],'min_samples_split':[2,4,8]}    
            scale_data = False            
            shift_labels = False
            feat_imp = True   #RF oob based feature importance

        else:
            print "Unknown model choice"
    
    else: 
        print 'Unknown output type'

    return {'model_clf':model_clf,'hyper_params':hyper_params,'scale_data':scale_data,'shift_labels':shift_labels,
            'feat_imp':feat_imp}

def computePerfMetrics(perf_df,col,value_list): 
    #col,value_list: slice df based on given col and list of values in that col
    CV_summary_df = pd.DataFrame(columns=['model','kf','Accuracy','AUC','CM'])
    idx=1    
    for model_choice in set(perf_df['model'].values):        
        CV_Acc = []
        CV_AUC = []
        CV_CM = []        
        for k in np.arange(1,11,1):            
            df_dx_subset = perf_df[(perf_df[col].isin(value_list))&(perf_df['kf']==k)&(perf_df['model']==model_choice)]            
            y_act = df_dx_subset['act_label'].values
            y_pred_score = df_dx_subset['pred_label'].values
            #print('len of {}'.format(len(df_dx_subset)))
            #print(np.shape(df_dx_subset['pred_prob'].values))
            y_pred_prob = np.vstack(df_dx_subset['pred_prob'].values)

            CV_Acc.append(acc(y_pred_score,y_act))                
            
            num_classes = len(set(y_act))
            if num_classes != 2:
                print("Only 1 class is present in the subset. Appending 0.5 to AUC list")
                CV_AUC.append(0.5)
                CV_summary_df.set_value(idx,'AUC',0.5)
            else:
                CV_AUC.append(roc_auc_score(y_act, y_pred_prob[:,1]))
                CV_summary_df.set_value(idx,'AUC',roc_auc_score(y_act, y_pred_prob[:,1])) 
                
            cm = confusion_matrix(y_pred_score,y_act)
            cm_normalized = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
            CV_CM.append(cm_normalized)             
            
            CV_summary_df.set_value(idx,'model',model_choice) 
            CV_summary_df.set_value(idx,'kf',k) 
            CV_summary_df.set_value(idx,'Accuracy',acc(y_pred_score,y_act))              
            CV_summary_df.set_value(idx,'CM',cm_normalized)             
            idx+=1
                        
        print model_choice
        print 'CV Acc (mean, std_err): {:04.2f}, {:04.2f}'.format(np.mean(CV_Acc),stats.sem(CV_Acc))
        print 'CV AUC (mean, std_err): {:04.2f}, {:04.2f}'.format(np.mean(CV_AUC),stats.sem(CV_AUC))
        print 'CV Confusion Matrix (mean): {}'.format(np.mean(np.array(CV_CM),axis=0))
        
    return CV_summary_df

# computes performance on a given subset of subjects (either Dx or quantiles)
def computePerfSubset(df_perf_dx_merge,col,subset_dict):    
    CV_summary_df_subset_concat = pd.DataFrame()
    for subset in subset_dict:
        print subset
        CV_summary_df_subset = computePerfMetrics(df_perf_dx_merge,col,subset_dict[subset])
        CV_summary_df_subset['subset']=np.tile(subset,len(CV_summary_df_subset))        
        CV_summary_df_subset_concat = CV_summary_df_subset_concat.append(CV_summary_df_subset,ignore_index=True)
        
    return CV_summary_df_subset_concat
    
    
#ROC curves
def plotROC(perf_df, model_list,input_choice, plot_luck, save_figure, save_path):

    marker_list = ['o','d','s','<','^','>','D','*','H']
    plt.style.use('seaborn-white')
    plt.rcParams['figure.figsize'] = (20, 20)

    mk=0

    for model_choice in model_list:
        _df = perf_df[(perf_df['model']==model_choice)]
        CV_fpr_tpr = []
        CV_fpr_tpr_thrsh = []
        for kf in np.arange(1,11,1): 
            y_act = np.squeeze(_df[_df['kf']==kf]['act_label'].values)
            y_pred_prob = np.vstack((_df[_df['kf']==kf]['pred_prob'].values))[:,1]
            fpr, tpr, thresholds = roc_curve(y_act, y_pred_prob)                     
            CV_fpr_tpr.append((fpr,tpr))        
            CV_fpr_tpr_thrsh.append(thresholds)

        mean_tpr = 0.0
        mean_fpr = np.linspace(0, 1, 100)
        all_tpr = []

        for i, (fpr, tpr) in enumerate(CV_fpr_tpr):
            mean_tpr += interp(mean_fpr, fpr, tpr)
            mean_tpr[0] = 0.0
            roc_auc = auc(fpr, tpr)

        mean_tpr /= len(CV_fpr_tpr)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)

        with sns.axes_style("whitegrid"):
            label_str = '{}, model: {},(area = {:3.2f})'.format(input_choice, model_choice, mean_auc)
            plt.plot(mean_fpr, mean_tpr, label=label_str, lw=2, marker = marker_list[mk],markersize=10)                    
            mk+=1

    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate',fontsize = 20)
    plt.ylabel('True Positive Rate',fontsize = 20)
    plt.title('Receiver operating characteristic',fontsize = 20)
    
    if plot_luck:
        plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck', lw=2)
        
    plt.legend(loc="lower right",fontsize = 15)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)

    print 'saving fig at: {}'.format(save_path)
    if save_figure:    
        plt.savefig(save_path, dpi=200) 

        
def get_sub_info(ptid,df,cs_cols,ct_cols,print_demo_table):
    # mainly to see outliers and its features
    # input: ptid, df (input_data from an exp), features (CS, CT_raw/CT_rate)
    # output: longform df/ series with columes to be plotted
    df_ptid = df[df['PTID'].isin(ptid_list)]
    if print_demo_table:
        print(df_ptid[['PTID']+cs_cols])
    return df_ptid[ct_cols]

# %%
# Train and Test models
# Load saved experimental setup

baseline_dir = '/projects/nbhagwat/Traj_prediction/ADNI/exp_setup/'
demo_cols = ['AGE','APOE4']
cohort = 'ALL_ADNI'
clinical_scale = 'ADAS13'
exp_name = 'Exp_502_{}_traj_{}_tp_var_tp'.format(cohort,clinical_scale)
use_cs = True
use_ct = True
var_tp = True
shuffle_labels = False # What's your performance with random labels. 

# Oversampling options
resample_train_data = False
sampling_tech = 'smote'

exp_setup_path = baseline_dir + 'KFolds/' + exp_name + '_sKF.pkl'
exp_setup = pickle.load( open(exp_setup_path, "rb" ) )

#Check if loading the correct experimental setup
if exp_name != exp_setup['exp_name']:
    print 'Incorrect exp_name. Selected:{}, Retrieved:{}'.format(exp_name, exp_setup['exp_name'])

else:
    print 'exp_name: {}'.format(exp_name)
    
    df = exp_setup['df']
    kf = exp_setup['sKF']
    
    feat_cols = []
    feat_sufix = ''
        
    if use_cs:
        print 'using CS columns'
        if var_tp:
            cs_cols = ['{}_bl'.format(clinical_scale),'{}_var_tp'.format(clinical_scale)] + demo_cols
        else:
            cs_cols = ['{}_bl'.format(clinical_scale)] + demo_cols
        feat_cols = feat_cols + cs_cols
        feat_sufix = feat_sufix + '_CS'
        
    if use_ct: 
        print 'using CT columns'
        if var_tp:
            ct_cols_bl = list(df.columns[pd.Series(df.columns).str.contains('CT_bl')])
            ct_cols_tp_rate = list(df.columns[pd.Series(df.columns).str.contains('CT_rate')])
            ct_cols = ct_cols_bl + ct_cols_tp_rate
        else:
            ct_cols = list(df.columns[pd.Series(df.columns).str.contains('CT')])
        
        feat_cols = feat_cols + ct_cols
        feat_sufix = feat_sufix + '_CT'    
    
    #print feat_cols
    
    # Model options
    model_list = ['LR_L1','SVC','RFC']
    output_type = 'classify' #needs to be either 'classify' or 'regression'

    save_CV_perf = False 

    ########################
    # Parallization configs for ipython notebook cluster    
    rc = ipp.Client()
    dview = rc[:]
    dview.push(dict(computeOuterFold = computeOuterFold))
    dview.push(dict(innerCVLoop = innerCVLoop))
    ########################

    df_perf_dict = {}
    df_perf_concat = pd.DataFrame(columns=['PTID','model','kf','act_label','pred_label','pred_prob'])
    idx = 1
    ####################
    ## Select a model ##
    ####################       
    for model_choice in model_list:
        model_def = getModel(model_choice,output_type)
        model_clf = model_def['model_clf']
        hyper_params = model_def['hyper_params']
        scale_data = model_def['scale_data']    
        shift_labels = model_def['shift_labels']    
        feat_imp = model_def['feat_imp']

        X_raw = np.array(df[feat_cols]) #Otherwise scaling and shifting will remain the same for next model. 
        y = np.array(df['traj'])     
        if shuffle_labels:
            print 'shuffling labels'
            np.random.shuffle(y)

        if shift_labels:
            y = 2*y-1 #SVM requires {-1,1}

        print 'model: {}, X shape {}'.format(model_choice, X_raw.shape)
        #Some paths to store models and performance stats
        CV_model_dir = baseline_dir + 'output/'
        save_model_path = CV_model_dir + exp_name + '_' + model_choice 
        save_model = False 

        # Create list of all the fold-subsets (needed for parallelization)
        Sub_train =[]
        Sub_valid = []
        X_train = []
        X_valid = []
        y_train = []
        y_valid = []    
        
        start_time = time.time()
        for train, valid in kf:
            Sub_train.append(df['PTID'].values[train]) 
            Sub_valid.append(df['PTID'].values[valid]) 
            X_tr = X_raw[train]
            y_tr = y[train]
            X_te = X_raw[valid]
            y_te = y[valid]

            if scale_data:
                scaler = preprocessing.StandardScaler().fit(X_tr)
                X_tr = scaler.transform(X_tr)
                X_te = scaler.transform(X_te)

            if resample_train_data:             
                #resample with tools from: https://github.com/scikit-learn-contrib/imbalanced-learn
                if sampling_tech == 'adasyn':                    
                    resamp_tech = ADASYN()
                elif sampling_tech == 'smote':
                    resamp_tech = SMOTE(kind='regular')
                else:
                    resamp_tech = RandomOverSampler()

                print 'using {} oversampling technique'.format(sampling_tech)                    
                X_resampled, y_resampled = resamp_tech.fit_sample(X_tr, y_tr)
                #print 'Original shapes: X{}, y:{}, y==1: {}'.format(X[train].shape, y[train].shape, np.sum(y[train]))
                #print 'Resampled shapes: X{}, y:{}, y==1: {}'.format(X_resampled.shape, y_resampled.shape, np.sum(y_resampled))                
                X_train.append(X_resampled)
                y_train.append(y_resampled)
            else:
                X_train.append(X_tr)
                y_train.append(y_tr)

            # No need to resample test data
            X_valid.append(X_te)            
            y_valid.append(y_te)

        # Compute various statistics on the predicted results acorss 10 Folds            
        if output_type == 'classify':        
            CV_Acc_valid=[] #Acuracy
            CV_CM_valid=[] #Confusion matrix
            CV_AUC_valid=[] #ROC and AUC                   
            CV_feat_imp = []
        else: 
            print 'unknown output type'

        predicted_CV_scores = []
        actual_CV_scores = []

        #Parallelize k-folds
        mapfunc = partial(computeOuterFold, model_clf=model_clf, hyper_params=hyper_params, 
                          output_type=output_type, model_type=model_choice)
        parallel_result = dview.map_sync(mapfunc, X_train, y_train, X_valid, y_valid,Sub_train,Sub_valid)    

        hp_dict = collections.defaultdict(list)
        for p, pr in enumerate(parallel_result):   
            df_perf = pd.DataFrame()
            if output_type == 'classify':
                y_pred_score = pr['predicted_fold_score']
                y_pred_prob = pr['predicted_fold_prob']
                y_act = pr['actual_fold_scores']
                predicted_CV_scores.append(y_pred_score)
                actual_CV_scores.append(y_act)        

                #Acc    
                CV_accuracy = acc(y_pred_score,y_act)
                CV_Acc_valid.append(CV_accuracy)                

                #AUC                
                CV_auc = roc_auc_score(y_act, y_pred_prob[:,1])
                CV_AUC_valid.append(CV_auc)

                #confusion matrix
                cm = confusion_matrix(y_pred_score,y_act)
                cm_normalized = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
                CV_CM_valid.append(cm_normalized)
                
                #Save perf method 1: df of all subjects
                df_perf['PTID'] = pr['Sub_valid']
                df_perf['model'] = np.tile(model_choice,len(y_act))
                df_perf['kf'] = np.tile(p+1,len(y_act))
                df_perf['act_label'] = y_act
                df_perf['pred_label'] = y_pred_score
                df_perf['pred_prob'] = list(y_pred_prob)
                
                df_perf_concat = df_perf_concat.append(df_perf)
                
                #Save perf method 2: dictionary of k folds
                df_perf_dict[idx] = {'model_choice':model_choice,'KF':p+1, 'act_scores':y_act,
                                    'pred_scores':y_pred_score,'pred_prob':y_pred_prob, 'Accuracy':CV_accuracy,
                                    'AUC':CV_auc,'CM':cm_normalized}
                idx+=1

            for hp in hyper_params:
                hp_dict[hp].append(pr['hp_dict'][hp])

        #Find out most frequent hyper-params during cross-val    
        hp_mode = {}
        for hp in hyper_params:
            hp_mode[hp] = mode(hp_dict[hp])[0][0]
        
        if output_type == 'classify':
            print 'most frequent hyper-params:' + str(hp_mode)
            print 'CV Acc (mean, std_err): {:04.2f}, {:04.2f}'.format(np.mean(CV_Acc_valid),stats.sem(CV_Acc_valid))
            print 'CV AUC (mean, std_err): {:04.2f}, {:04.2f}'.format(np.mean(CV_AUC_valid),stats.sem(CV_AUC_valid))
            print 'CV Confusion Matrix (mean): {}'.format(np.mean(np.array(CV_CM_valid),axis=0))
           
            plot_name = 'ROC'
        
        #timer
        end_time = time.time()
        compute_time = (end_time - start_time)/60.0
        print 'compute time: {}, {:3.2f} mins'.format(model_choice,compute_time)
        print ''
        
    #Save df style dictionaly for seaborn plots
    # df_perf_dict_path = baseline_dir + 'df_perf_dict_{}_{}.pkl'.format(exp_name, Clinical_Scale)                
    # pickleIt(df_perf_dict,df_perf_dict_path)
    # print 'saving results at: {}'.format(df_perf_dict_path)
# Out:
# exp_name: Exp_502_ALL_ADNI_traj_ADAS13_tp_var_tp
# using CS columns
# using CT columns
# model: LR_L1, X shape (1115, 160)
# most frequent hyper-params:{'C': array([ 0.01])}
# CV Acc (mean, std_err): 0.94, 0.00
# CV AUC (mean, std_err): 0.99, 0.00
# CV Confusion Matrix (mean): [[ 0.92465225  0.07534775]
#  [ 0.05499252  0.94500748]]
# compute time: LR_L1, 0.06 mins
#
# model: SVC, X shape (1115, 160)

# %%
#Save df and dictionaries for seaborn plots
perf_dict_path = baseline_dir + 'perf_stats/df_perf_dict_{}_feat{}_dict.pkl'.format(exp_name,feat_sufix)                
perf_df_path = baseline_dir + 'perf_stats/df_perf_dict_{}_feat{}_df.pkl'.format(exp_name,feat_sufix)                
pickleIt(df_perf_dict,perf_dict_path)
df_perf_concat.to_pickle(perf_df_path)

print 'saving results at: {}'.format(perf_df_path)
# Out:
# saving results at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/perf_stats/df_perf_dict_Exp_502_ALL_ADNI_traj_ADAS13_tp_var_tp_feat_CS_CT_df.pkl

# %%
# Compute per DX_list performances 
clinical_scale = 'MMSE'
cohort = 'ALL_ADNI'
exp_name = 'Exp_502_{}_traj_{}_tp_var_tp'.format(cohort,clinical_scale)
exp_setup_path = baseline_dir + 'KFolds/' + exp_name + '_sKF.pkl'
exp_setup = pickle.load( open(exp_setup_path, "rb" ) )
tmp_df = pd.DataFrame()

#Check if loading the correct experimental setup
if exp_name != exp_setup['exp_name']:
    print 'Incorrect exp_name. Selected:{}, Retrieved:{}'.format(exp_name, exp_setup['exp_name'])
else:    
    df = exp_setup['df']
    print 'exp_name: {}, number of subjects:{}'.format(exp_name,len(set(df['PTID'].values)))
    print 'label counds: 0:{}, 1:{}'.format(len(df[df['traj']==0]),len(df[df['traj']==1]))
#     df['traj'].replace({0:1,1:0},inplace=True)
#     print 'label counds: 0:{}, 1:{}'.format(len(df[df['traj']==0]),len(df[df['traj']==1]))
    
cs_bl = clinical_scale + '_bl'
cs_var_tp = clinical_scale + '_var_tp'
cs_bl_var_tp = clinical_scale + '_bl_var_tp'

#Use list of PTIDs as quantile values
# quantile_col= 'PTID'
# uncertain_bl = pd.read_pickle(baseline_dir+'ADNI_trajectory_MMSE_bl_uncertain_subs_df.pkl')
# uncertain_tp = pd.read_pickle(baseline_dir+'ADNI_trajectory_MMSE_m12_uncertain_subs_df.pkl')

# quant_subset_dict = {'BL_Uncertain':uncertain_bl['PTID'].values,
#                      'BL_TP_Uncertain':uncertain_tp['PTID'].values,                     
#                      'all':df['PTID'].values} 


# #Divide up quantiles
quantile_col = cs_bl_var_tp + '_quantile'

bl_high = 28
bl_low = 27
tp_delta_high = 1
tp_delta_low = 1


df[quantile_col] = np.zeros(len(df))

df.loc[(df[cs_bl] > bl_high) | (df[cs_bl] < bl_low),quantile_col] = 'BL_Easy'
df.loc[((df[cs_bl] <= bl_high) & (df[cs_bl] >= bl_low)) & 
       ((df[cs_bl] - df[cs_var_tp] <= tp_delta_low) | (df[cs_var_tp] - df[cs_bl]  <= tp_delta_high)),
       quantile_col] = 'BL_TP_Uncertain'
df.loc[((df[cs_bl] <= bl_high) & (df[cs_bl] >= bl_low)) & 
       ((df[cs_bl] - df[cs_var_tp] > tp_delta_low) | (df[cs_var_tp] - df[cs_bl]  > tp_delta_high)),
       quantile_col] = 'BL_TP_Easy'

quant_subset_dict = {'BL_TP_Uncertain':['BL_TP_Uncertain'],
                     'BL_Easy':['BL_Easy'],
                     'BL_TP_Easy':['BL_TP_Easy'],
                     'all':['BL_TP_Easy','BL_Easy','BL_TP_Uncertain']} 

count_list = []
for q in quant_subset_dict.keys():
    count_list.append(len(df[df[quantile_col]==q]))
    print 'quant {}, count:{},{}, mean traj0 bl:{:4.2f}, var_tp:{:4.2f}, traj1 mean bl:{:4.2f}, var_tp:{:4.2f}'.format(q, 
                                                             len(df[(df[quantile_col]==q) & (df['traj']==0)]),
                                                             len(df[(df[quantile_col]==q) & (df['traj']==1)]),
                                                             np.mean(df[(df[quantile_col]==q) & (df['traj']==0)][cs_bl]),
                                                             np.mean(df[(df[quantile_col]==q) & (df['traj']==0)][cs_var_tp]),
                                                             np.mean(df[(df[quantile_col]==q) & (df['traj']==1)][cs_bl]),
                                                             np.mean(df[(df[quantile_col]==q) & (df['traj']==1)][cs_var_tp]))
print('Sum of all quants: {}'.format(np.sum(count_list)))


# --------Baseline + TP quantiles----------------
# Create low and high quantiles (not equal in number due to overlapping scores)
traj_0_median_bl = np.median(df[df['traj']==0][cs_bl].values)
traj_0_median_var_tp = np.median(df[df['traj']==0][cs_var_tp].values)
traj_1_median_bl = np.median(df[df['traj']==1][cs_bl].values)
traj_1_median_var_tp = np.median(df[df['traj']==1][cs_var_tp].values)

print traj_0_median_bl, traj_0_median_var_tp, traj_1_median_bl, traj_1_median_var_tp

df.loc[(df['traj']==0)&(df[cs_bl] < traj_0_median_bl)&(df[cs_var_tp] < traj_0_median_var_tp)
       ,quantile_col] = 'T0_low_low'
df.loc[(df['traj']==0)&(df[cs_bl] < traj_0_median_bl)&(df[cs_var_tp] >= traj_0_median_var_tp)
       ,quantile_col] = 'T0_low_high'
df.loc[(df['traj']==0)&(df[cs_bl] >= traj_0_median_bl)&(df[cs_var_tp] < traj_0_median_var_tp)
       ,quantile_col] = 'T0_high_low'
df.loc[(df['traj']==0)&(df[cs_bl] >= traj_0_median_bl)&(df[cs_var_tp] >= traj_0_median_var_tp)
       ,quantile_col] = 'T0_high_high'

df.loc[(df['traj']==1)&(df[cs_bl] < traj_1_median_bl)&(df[cs_var_tp] < traj_1_median_var_tp)
       ,quantile_col] = 'T1_low_low'
df.loc[(df['traj']==1)&(df[cs_bl] < traj_1_median_bl)&(df[cs_var_tp] >= traj_1_median_var_tp)
       ,quantile_col] = 'T1_low_high'
df.loc[(df['traj']==1)&(df[cs_bl] >= traj_1_median_bl)&(df[cs_var_tp]< traj_1_median_var_tp)
       ,quantile_col] = 'T1_high_low'
df.loc[(df['traj']==1)&(df[cs_bl] >= traj_1_median_bl)&(df[cs_var_tp] >= traj_1_median_var_tp)
       ,quantile_col] = 'T1_high_high'

quants = ['T0_low_low','T0_low_high','T0_high_low','T0_high_high',
          'T1_low_low','T1_low_high','T1_high_low','T1_high_high']

quant_subset_dict = {'steady_scores_easy':['T0_high_high','T1_low_low'],
                     'steady_scores_tough':['T0_low_low','T1_high_high'],
                     'fluctuating_scores':['T0_low_high','T1_high_low','T0_high_low','T1_low_high'],
                     'all':quants} 

count_list = []
for q in quants:
    count_list.append(len(df[df[quantile_col]==q]))
    print 'quant {}, count:{}, mean bl:{}, var_tp:{}'.format(q, len(df[df[quantile_col]==q]),
                                                             np.mean(df[df[quantile_col]==q][cs_bl]),
                                                             np.mean(df[df[quantile_col]==q][cs_var_tp]))
print('Sum of all quants: {}'.format(np.sum(count_list)))
                     

## --------Baseline quantiles----------------                    
# df.loc[(df['traj']==0)&(df[cs_bl] >= traj_0_median),cs_bl + '_quantile'] = 'T0_high'
# df.loc[(df['traj']==1)&(df[cs_bl] <= traj_1_median),cs_bl + '_quantile'] = 'T1_low'
# df.loc[(df['traj']==1)&(df[cs_bl] > traj_1_median),cs_bl + '_quantile'] = 'T1_high'
# df.loc[(df['traj']==0)&(df[cs_bl] < traj_0_median),cs_bl + '_quantile'] = 'T0_low'
# df.loc[(df['traj']==0)&(df[cs_bl] >= traj_0_median),cs_bl + '_quantile'] = 'T0_high'
# df.loc[(df['traj']==1)&(df[cs_bl] <= traj_1_median),cs_bl + '_quantile'] = 'T1_low'
# df.loc[(df['traj']==1)&(df[cs_bl] > traj_1_median),cs_bl + '_quantile'] = 'T1_high'
#quants = ['T0_low','T0_high','T1_low','T1_high']
#quant_subset_dict = {'quant_list_med':['T0_low','T1_high'], 'all':['T0_low','T1_high','T0_high','T1_low']} 


## --------DX quants------------
# quantile_col = 'DX_bl'
# quant_subset_dict = {'all':['CN','SMC','EMCI','LMCI','AD'], 'cn+ad':['AD','CN'], 'smc+mci':['SMC','EMCI','LMCI']}


# #Load multiple perf_dfs
df_subx_perf_paths = {
    'tp: bl, feat: cs':'df_perf_dict_Exp_501_{}_traj_{}_tp_bl_feat_CS_df.pkl'.format(cohort,clinical_scale),
    'tp: bl, feat: ct':'df_perf_dict_Exp_501_{}_traj_{}_tp_bl_feat_CT_df.pkl'.format(cohort,clinical_scale),
    'tp: bl, feat: cs+ct':'df_perf_dict_Exp_501_{}_traj_{}_tp_bl_feat_CS_CT_df.pkl'.format(cohort,clinical_scale),
    'tp: bl+1, feat: cs':'df_perf_dict_Exp_502_{}_traj_{}_tp_var_tp_feat_CS_df.pkl'.format(cohort,clinical_scale),
    'tp: bl+1, feat: ct':'df_perf_dict_Exp_502_{}_traj_{}_tp_var_tp_feat_CT_df.pkl'.format(cohort,clinical_scale),
    'tp: bl+1, feat: cs+ct':'df_perf_dict_Exp_502_{}_traj_{}_tp_var_tp_feat_CS_CT_df.pkl'.format(cohort,clinical_scale)
}

CV_summary_df = pd.DataFrame()
for exp_idx in df_subx_perf_paths:    
    perf_df_path = baseline_dir + 'perf_stats/{}'.format(df_subx_perf_paths[exp_idx])                
    df_perf_concat = pd.read_pickle(perf_df_path)
    df_perf_dx_merge = pd.merge(df_perf_concat,df[['PTID','ORIGPROT','{}_bl'.format(clinical_scale),quantile_col,
                                                   '{}_var_tp'.format(clinical_scale)]],
                                on='PTID',how='inner') 
    
    print 'exp_idx: {}, subx: {}'.format(exp_idx, len(df_perf_dx_merge))
    CV_summary_df_feat = computePerfSubset(df_perf_dx_merge,quantile_col,quant_subset_dict)
    CV_summary_df_feat['Input'] = np.tile(exp_idx, len(CV_summary_df_feat))    
    CV_summary_df = CV_summary_df.append(CV_summary_df_feat)
     
# Regular ANNs
#Load multiple ANN_perf_dfs
df_subx_perf_paths = {
    'tp: bl, feat: cs':'Exp_501_{}_traj_{}_tp_bl_ANN_Layer2_CS_df_perf.pkl'.format(cohort,clinical_scale),
    'tp: bl, feat: ct':'Exp_501_{}_traj_{}_tp_bl_ANN_Layer2_CT_df_perf.pkl'.format(cohort,clinical_scale),
    'tp: bl, feat: cs+ct':'Exp_501_{}_traj_{}_tp_bl_ANN_Layer2_CS_CT_df_perf.pkl'.format(cohort,clinical_scale),     
    'tp: bl+1, feat: cs': 'Exp_502_{}_traj_{}_tp_var_tp_ANN_Layer2_CS_df_perf.pkl'.format(cohort,clinical_scale),
    'tp: bl+1, feat: ct': 'Exp_502_{}_traj_{}_tp_var_tp_ANN_Layer2_CT_df_perf.pkl'.format(cohort,clinical_scale),
    'tp: bl+1, feat: cs+ct':'Exp_502_{}_traj_{}_tp_var_tp_ANN_Layer2_CS_CT_df_perf.pkl'.format(cohort,clinical_scale)
}

for exp_idx in df_subx_perf_paths:
    print 'exp_idx: ' + exp_idx
    perf_df_path = baseline_dir + 'TF_perf/benchmarks/{}'.format(df_subx_perf_paths[exp_idx])                
    df_perf_concat = pd.read_pickle(perf_df_path)
    df_perf_dx_merge = pd.merge(df_perf_concat,df[['PTID','ORIGPROT','{}_bl'.format(clinical_scale),quantile_col,
                                                   '{}_var_tp'.format(clinical_scale)]],
                               on='PTID',how='inner')       
    CV_summary_df_feat = computePerfSubset(df_perf_dx_merge,quantile_col,quant_subset_dict)
    CV_summary_df_feat['Input'] = np.tile(exp_idx, len(CV_summary_df_feat))    
    CV_summary_df = CV_summary_df.append(CV_summary_df_feat)

    ####tmp#####
    df_perf_dx_merge['Input'] = np.tile(exp_idx, len(df_perf_dx_merge))    
    tmp_df = tmp_df.append(df_perf_dx_merge)
    ############
    
# # #Load multiple Siamese_perf_dfs
# df_subx_perf_paths = {'tp: bl+1, feat: cs':'Exp_102_{}_traj_{}_tp_var_tp_feat_CS_Siamese_Layer2_dist_mod_slim_df_perf.pkl'.format(cohort,clinical_scale),
#                      'tp: bl+1, feat: cs+ct+aux':'Exp_102_{}_traj_{}_tp_var_tp_feat_CS_CT_aux_Siamese_Layer2_dist_mod_slim_df_perf.pkl'.format(cohort,clinical_scale),
#                      'tp: bl+1, feat: cs+ct':'Exp_102_{}_traj_{}_tp_var_tp_feat_CS_CT_Siamese_Layer2_slim_df_perf.pkl'.format(cohort,clinical_scale),
#                      'tp: bl+1, feat: cs+ct+aux_mod':'Exp_102_{}_traj_{}_tp_var_tp_feat_CS_CT_aux_Siamese_Layer2_dist_mod_learn_slim_df_perf.pkl'.format(cohort,clinical_scale)}

df_subx_perf_paths = {'tp: bl+1, feat: cs+ct':'Exp_502_{}_traj_{}_tp_var_tp_feat_CS_CT_aux_Siamese_Layer2_dist_mod_slim_df_perf_tanh.pkl'.format(cohort,clinical_scale),
                      'tp: bl+1, feat: ct':'Exp_502_{}_traj_{}_tp_var_tp_feat_CT_Siamese_Layer2_dist_mod_slim_df_perf.pkl'.format(cohort,clinical_scale)
                     }    

for exp_idx in df_subx_perf_paths:
    print 'exp_idx: ' + exp_idx
    perf_df_path = baseline_dir + 'TF_perf/benchmarks/{}'.format(df_subx_perf_paths[exp_idx])                
    
    print perf_df_path
    df_perf_concat = pd.read_pickle(perf_df_path)
    df_perf_dx_merge = pd.merge(df_perf_concat,df[['PTID','ORIGPROT','{}_bl'.format(clinical_scale),
                                                   '{}_var_tp'.format(clinical_scale),'APOE4',quantile_col,
                                                   ]],on='PTID',how='inner')  
    
    CV_summary_df_feat = computePerfSubset(df_perf_dx_merge,quantile_col,quant_subset_dict)
    CV_summary_df_feat['Input'] = np.tile(exp_idx, len(CV_summary_df_feat))    
    CV_summary_df = CV_summary_df.append(CV_summary_df_feat)
# Out:
# exp_name: Exp_502_ALL_ADNI_traj_MMSE_tp_var_tp, number of subjects:1116
# label counds: 0:674, 1:442
# quant BL_Easy, count:507,357, mean traj0 bl:29.12, var_tp:28.90, traj1 mean bl:24.70, var_tp:22.85
# quant BL_TP_Easy, count:74,44, mean traj0 bl:27.69, var_tp:29.22, traj1 mean bl:27.50, var_tp:24.43
# quant BL_TP_Uncertain, count:93,41, mean traj0 bl:27.78, var_tp:27.98, traj1 mean bl:27.39, var_tp:27.02
# quant all, count:0,0, mean traj0 bl: nan, var_tp: nan, traj1 mean bl: nan, var_tp: nan
# Sum of all quants: 1116
# 29.0 29.0 25.0 24.0
# quant T0_low_low, count:110, mean bl:27.0181818182, var_tp:27.2909090909
# quant T0_low_high, count:108, mean bl:27.4074074074, var_tp:29.5555555556
# quant T0_high_low, count:109, mean bl:29.3669724771, var_tp:27.2201834862
# quant T0_high_high, count:347, mean bl:29.5850144092, var_tp:29.5590778098
# quant T1_low_low, count:112, mean bl:22.2232142857, var_tp:18.8571428571
# quant T1_low_high, count:41, mean bl:23.512195122, var_tp:25.2682926829
# quant T1_high_low, count:65, mean bl:26.0, var_tp:20.9538461538
# quant T1_high_high, count:224, mean bl:26.8214285714, var_tp:26.0267857143
# Sum of all quants: 1116
# exp_idx: tp: bl+1, feat: cs+ct, subx: 3348
# all
# RFC
# CV Acc (mean, std_err): 0.88, 0.01
# CV AUC (mean, std_err): 0.96, 0.00
# CV Confusion Matrix (mean): [[ 0.88165089  0.11834911]
#  [ 0.11259705  0.88740295]]
# LR_L1
# CV Acc (mean, std_err): 0.91, 0.01
# CV AUC (mean, std_err): 0.97, 0.01
# CV Confusion Matrix (mean): [[ 0.93062046  0.06937954]
#  [ 0.10521674  0.89478326]]
# SVC
# CV Acc (mean, std_err): 0.89, 0.01
# CV AUC (mean, std_err): 0.96, 0.01
# CV Confusion Matrix (mean): [[ 0.91875663  0.08124337]
#  [ 0.1403528   0.8596472 ]]
# steady_scores_tough
# RFC
# CV Acc (mean, std_err): 0.67, 0.02
# CV AUC (mean, std_err): 0.78, 0.02
# CV Confusion Matrix (mean): [[ 0.50522947  0.49477053]
#  [ 0.17665959  0.82334041]]
# LR_L1
# CV Acc (mean, std_err): 0.76, 0.03
# CV AUC (mean, std_err): 0.80, 0.03
# CV Confusion Matrix (mean): [[ 0.63821659  0.36178341]
#  [ 0.15602047  0.84397953]]
# SVC
# CV Acc (mean, std_err): 0.72, 0.01
# CV AUC (mean, std_err): 0.80, 0.02
# CV Confusion Matrix (mean): [[ 0.58772158  0.41227842]
#  [ 0.18870155  0.81129845]]
# fluctuating_scores
# RFC
# CV Acc (mean, std_err): 0.94, 0.01
# CV AUC (mean, std_err): 0.99, 0.00
# CV Confusion Matrix (mean): [[ 0.96434946  0.03565054]
#  [ 0.10944056  0.89055944]]
# LR_L1
# CV Acc (mean, std_err): 0.96, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99545455  0.00454545]
#  [ 0.09527778  0.90472222]]
# SVC
# CV Acc (mean, std_err): 0.95, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99089027  0.00910973]
#  [ 0.12431159  0.87568841]]
# steady_scores_easy
# RFC
# CV Acc (mean, std_err): 0.99, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99767442  0.00232558]
#  [ 0.01428571  0.98571429]]
# LR_L1
# CV Acc (mean, std_err): 0.99, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.          0.        ]
#  [ 0.02291667  0.97708333]]
# SVC
# CV Acc (mean, std_err): 0.98, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.          0.        ]
#  [ 0.06629329  0.93370671]]
# exp_idx: tp: bl, feat: cs+ct, subx: 3348
# all
# RFC
# CV Acc (mean, std_err): 0.85, 0.01
# CV AUC (mean, std_err): 0.91, 0.01
# CV Confusion Matrix (mean): [[ 0.85676066  0.14323934]
#  [ 0.15454105  0.84545895]]
# LR_L1
# CV Acc (mean, std_err): 0.85, 0.01
# CV AUC (mean, std_err): 0.93, 0.01
# CV Confusion Matrix (mean): [[ 0.89254617  0.10745383]
#  [ 0.19425354  0.80574646]]
# SVC
# CV Acc (mean, std_err): 0.85, 0.01
# CV AUC (mean, std_err): 0.93, 0.01
# CV Confusion Matrix (mean): [[ 0.88442285  0.11557715]
#  [ 0.19021118  0.80978882]]
# steady_scores_tough
# RFC
# CV Acc (mean, std_err): 0.64, 0.03
# CV AUC (mean, std_err): 0.68, 0.03
# CV Confusion Matrix (mean): [[ 0.4701462   0.5298538 ]
#  [ 0.20506344  0.79493656]]
# LR_L1
# CV Acc (mean, std_err): 0.66, 0.02
# CV AUC (mean, std_err): 0.67, 0.03
# CV Confusion Matrix (mean): [[ 0.49795303  0.50204697]
#  [ 0.23721322  0.76278678]]
# SVC
# CV Acc (mean, std_err): 0.67, 0.02
# CV AUC (mean, std_err): 0.71, 0.02
# CV Confusion Matrix (mean): [[ 0.50460051  0.49539949]
#  [ 0.21792348  0.78207652]]
# fluctuating_scores
# RFC
# CV Acc (mean, std_err): 0.88, 0.01
# CV AUC (mean, std_err): 0.95, 0.01
# CV Confusion Matrix (mean): [[ 0.92144845  0.07855155]
#  [ 0.17553696  0.82446304]]
# LR_L1
# CV Acc (mean, std_err): 0.87, 0.02
# CV AUC (mean, std_err): 0.96, 0.01
# CV Confusion Matrix (mean): [[ 0.95911765  0.04088235]
#  [ 0.24833076  0.75166924]]
# SVC
# CV Acc (mean, std_err): 0.87, 0.02
# CV AUC (mean, std_err): 0.96, 0.01
# CV Confusion Matrix (mean): [[ 0.9579085   0.0420915 ]
#  [ 0.25006529  0.74993471]]
# steady_scores_easy
# RFC
# CV Acc (mean, std_err): 0.98, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99767442  0.00232558]
#  [ 0.055       0.945     ]]
# LR_L1
# CV Acc (mean, std_err): 0.98, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99767442  0.00232558]
#  [ 0.06040404  0.93959596]]
# SVC
# CV Acc (mean, std_err): 0.98, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99772727  0.00227273]
#  [ 0.07330447  0.92669553]]
# exp_idx: tp: bl+1, feat: ct, subx: 3348
# all
# RFC
# CV Acc (mean, std_err): 0.76, 0.01
# CV AUC (mean, std_err): 0.82, 0.01
# CV Confusion Matrix (mean): [[ 0.78105461  0.21894539]
#  [ 0.27823634  0.72176366]]
# LR_L1
# CV Acc (mean, std_err): 0.77, 0.02
# CV AUC (mean, std_err): 0.83, 0.02
# CV Confusion Matrix (mean): [[ 0.83069333  0.16930667]
#  [ 0.31017422  0.68982578]]
# SVC
# CV Acc (mean, std_err): 0.76, 0.01
# CV AUC (mean, std_err): 0.82, 0.01
# CV Confusion Matrix (mean): [[ 0.82954169  0.17045831]
#  [ 0.31742054  0.68257946]]
# steady_scores_tough
# RFC
# CV Acc (mean, std_err): 0.59, 0.02
# CV AUC (mean, std_err): 0.70, 0.02
# CV Confusion Matrix (mean): [[ 0.4258424   0.5741576 ]
#  [ 0.19852144  0.80147856]]
# LR_L1
# CV Acc (mean, std_err): 0.67, 0.03
# CV AUC (mean, std_err): 0.72, 0.03
# CV Confusion Matrix (mean): [[ 0.52103776  0.47896224]
#  [ 0.19033411  0.80966589]]
# SVC
# CV Acc (mean, std_err): 0.67, 0.02
# CV AUC (mean, std_err): 0.72, 0.03
# CV Confusion Matrix (mean): [[ 0.51530399  0.48469601]
#  [ 0.18360848  0.81639152]]
# fluctuating_scores
# RFC
# CV Acc (mean, std_err): 0.80, 0.02
# CV AUC (mean, std_err): 0.86, 0.02
# CV Confusion Matrix (mean): [[ 0.84715635  0.15284365]
#  [ 0.30758408  0.69241592]]
# LR_L1
# CV Acc (mean, std_err): 0.76, 0.03
# CV AUC (mean, std_err): 0.85, 0.03
# CV Confusion Matrix (mean): [[ 0.86674603  0.13325397]
#  [ 0.37270461  0.62729539]]
# SVC
# CV Acc (mean, std_err): 0.80, 0.02
# CV AUC (mean, std_err): 0.86, 0.02
# CV Confusion Matrix (mean): [[ 0.89106487  0.10893513]
#  [ 0.32462714  0.67537286]]
# steady_scores_easy
# RFC
# CV Acc (mean, std_err): 0.85, 0.01
# CV AUC (mean, std_err): 0.91, 0.01
# CV Confusion Matrix (mean): [[ 0.95240379  0.04759621]
#  [ 0.34885342  0.65114658]]
# LR_L1
# CV Acc (mean, std_err): 0.84, 0.01
# CV AUC (mean, std_err): 0.94, 0.01
# CV Confusion Matrix (mean): [[ 0.98006846  0.01993154]
#  [ 0.38994689  0.61005311]]
# SVC
# CV Acc (mean, std_err): 0.81, 0.01
# CV AUC (mean, std_err): 0.91, 0.01
# CV Confusion Matrix (mean): [[ 0.97210975  0.02789025]
#  [ 0.43715138  0.56284862]]
# exp_idx: tp: bl, feat: ct, subx: 3348
# all
# RFC
# CV Acc (mean, std_err): 0.75, 0.01
# CV AUC (mean, std_err): 0.81, 0.01
# CV Confusion Matrix (mean): [[ 0.76130086  0.23869914]
#  [ 0.27546745  0.72453255]]
# LR_L1
# CV Acc (mean, std_err): 0.76, 0.01
# CV AUC (mean, std_err): 0.82, 0.02
# CV Confusion Matrix (mean): [[ 0.82404818  0.17595182]
#  [ 0.32262727  0.67737273]]
# SVC
# CV Acc (mean, std_err): 0.77, 0.01
# CV AUC (mean, std_err): 0.82, 0.01
# CV Confusion Matrix (mean): [[ 0.83051962  0.16948038]
#  [ 0.3126177   0.6873823 ]]
# steady_scores_tough
# RFC
# CV Acc (mean, std_err): 0.57, 0.02
# CV AUC (mean, std_err): 0.70, 0.03
# CV Confusion Matrix (mean): [[ 0.4176257   0.5823743 ]
#  [ 0.17917004  0.82082996]]
# LR_L1
# CV Acc (mean, std_err): 0.69, 0.02
# CV AUC (mean, std_err): 0.74, 0.03
# CV Confusion Matrix (mean): [[ 0.52085461  0.47914539]
#  [ 0.16468941  0.83531059]]
# SVC
# CV Acc (mean, std_err): 0.70, 0.02
# CV AUC (mean, std_err): 0.73, 0.02
# CV Confusion Matrix (mean): [[ 0.53794118  0.46205882]
#  [ 0.1619225   0.8380775 ]]
# fluctuating_scores
# RFC
# CV Acc (mean, std_err): 0.78, 0.02
# CV AUC (mean, std_err): 0.83, 0.02
# CV Confusion Matrix (mean): [[ 0.82300678  0.17699322]
#  [ 0.30955211  0.69044789]]
# LR_L1
# CV Acc (mean, std_err): 0.75, 0.02
# CV AUC (mean, std_err): 0.83, 0.02
# CV Confusion Matrix (mean): [[ 0.86231003  0.13768997]
#  [ 0.38846587  0.61153413]]
# SVC
# CV Acc (mean, std_err): 0.76, 0.02
# CV AUC (mean, std_err): 0.84, 0.02
# CV Confusion Matrix (mean): [[ 0.8637331   0.1362669 ]
#  [ 0.38432692  0.61567308]]
# steady_scores_easy
# RFC
# CV Acc (mean, std_err): 0.85, 0.01
# CV AUC (mean, std_err): 0.91, 0.01
# CV Confusion Matrix (mean): [[ 0.94154201  0.05845799]
#  [ 0.33789546  0.66210454]]
# LR_L1
# CV Acc (mean, std_err): 0.81, 0.02
# CV AUC (mean, std_err): 0.90, 0.02
# CV Confusion Matrix (mean): [[ 0.96323765  0.03676235]
#  [ 0.43188741  0.56811259]]
# SVC
# CV Acc (mean, std_err): 0.82, 0.01
# CV AUC (mean, std_err): 0.92, 0.02
# CV Confusion Matrix (mean): [[ 0.96678251  0.03321749]
#  [ 0.42011099  0.57988901]]
# exp_idx: tp: bl, feat: cs, subx: 3348
# all
# RFC
# CV Acc (mean, std_err): 0.83, 0.01
# CV AUC (mean, std_err): 0.90, 0.01
# CV Confusion Matrix (mean): [[ 0.86750705  0.13249295]
#  [ 0.22416342  0.77583658]]
# LR_L1
# CV Acc (mean, std_err): 0.84, 0.01
# CV AUC (mean, std_err): 0.90, 0.01
# CV Confusion Matrix (mean): [[ 0.87989889  0.12010111]
#  [ 0.206468    0.793532  ]]
# SVC
# CV Acc (mean, std_err): 0.84, 0.01
# CV AUC (mean, std_err): 0.91, 0.01
# CV Confusion Matrix (mean): [[ 0.87196937  0.12803063]
#  [ 0.19427026  0.80572974]]
# steady_scores_tough
# RFC
# CV Acc (mean, std_err): 0.64, 0.03
# CV AUC (mean, std_err): 0.66, 0.02
# CV Confusion Matrix (mean): [[ 0.46140027  0.53859973]
#  [ 0.24761117  0.75238883]]
# LR_L1
# CV Acc (mean, std_err): 0.61, 0.03
# CV AUC (mean, std_err): 0.57, 0.03
# CV Confusion Matrix (mean): [[ 0.43289322  0.56710678]
#  [ 0.27952577  0.72047423]]
# SVC
# CV Acc (mean, std_err): 0.62, 0.02
# CV AUC (mean, std_err): 0.61, 0.02
# CV Confusion Matrix (mean): [[ 0.44084804  0.55915196]
#  [ 0.26338128  0.73661872]]
# fluctuating_scores
# RFC
# CV Acc (mean, std_err): 0.84, 0.02
# CV AUC (mean, std_err): 0.92, 0.02
# CV Confusion Matrix (mean): [[ 0.92331351  0.07668649]
#  [ 0.26419351  0.73580649]]
# LR_L1
# CV Acc (mean, std_err): 0.86, 0.01
# CV AUC (mean, std_err): 0.94, 0.01
# CV Confusion Matrix (mean): [[ 0.95894841  0.04105159]
#  [ 0.27299756  0.72700244]]
# SVC
# CV Acc (mean, std_err): 0.86, 0.02
# CV AUC (mean, std_err): 0.94, 0.01
# CV Confusion Matrix (mean): [[ 0.94730952  0.05269048]
#  [ 0.2660715   0.7339285 ]]
# steady_scores_easy
# RFC
# CV Acc (mean, std_err): 0.96, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.          0.        ]
#  [ 0.13357198  0.86642802]]
# LR_L1
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.  0.]
#  [ 0.  1.]]
# SVC
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.  0.]
#  [ 0.  1.]]
# exp_idx: tp: bl+1, feat: cs, subx: 2925
# all
# RFC
# CV Acc (mean, std_err): 0.89, 0.01
# CV AUC (mean, std_err): 0.95, 0.01
# CV Confusion Matrix (mean): [[ 0.911811    0.088189  ]
#  [ 0.14802348  0.85197652]]
# LR_L1
# CV Acc (mean, std_err): 0.90, 0.01
# CV AUC (mean, std_err): 0.96, 0.01
# CV Confusion Matrix (mean): [[ 0.92640801  0.07359199]
#  [ 0.14031962  0.85968038]]
# SVC
# CV Acc (mean, std_err): 0.90, 0.01
# CV AUC (mean, std_err): 0.96, 0.01
# CV Confusion Matrix (mean): [[ 0.92994974  0.07005026]
#  [ 0.15732418  0.84267582]]
# steady_scores_tough
# RFC
# CV Acc (mean, std_err): 0.70, 0.02
# CV AUC (mean, std_err): 0.73, 0.04
# CV Confusion Matrix (mean): [[ 0.58185592  0.41814408]
#  [ 0.20091991  0.79908009]]
# LR_L1
# CV Acc (mean, std_err): 0.71, 0.03
# CV AUC (mean, std_err): 0.74, 0.03
# CV Confusion Matrix (mean): [[ 0.6098532   0.3901468 ]
#  [ 0.21976011  0.78023989]]
# SVC
# CV Acc (mean, std_err): 0.70, 0.02
# CV AUC (mean, std_err): 0.75, 0.03
# CV Confusion Matrix (mean): [[ 0.61130342  0.38869658]
#  [ 0.22843786  0.77156214]]
# fluctuating_scores
# RFC
# CV Acc (mean, std_err): 0.93, 0.01
# CV AUC (mean, std_err): 0.99, 0.00
# CV Confusion Matrix (mean): [[ 0.97847339  0.02152661]
#  [ 0.16857143  0.83142857]]
# LR_L1
# CV Acc (mean, std_err): 0.97, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.          0.        ]
#  [ 0.10830087  0.89169913]]
# SVC
# CV Acc (mean, std_err): 0.95, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.          0.        ]
#  [ 0.15334776  0.84665224]]
# steady_scores_easy
# RFC
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.          0.        ]
#  [ 0.00909091  0.99090909]]
# LR_L1
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.  0.]
#  [ 0.  1.]]
# SVC
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.  0.]
#  [ 0.  1.]]
# exp_idx: tp: bl+1, feat: cs+ct
# all
# ANN_Layer2
# CV Acc (mean, std_err): 0.89, 0.01
# CV AUC (mean, std_err): 0.96, 0.01
# CV Confusion Matrix (mean): [[ 0.91892051  0.08107949]
#  [ 0.13915821  0.86084179]]
# steady_scores_tough
# ANN_Layer2
# CV Acc (mean, std_err): 0.72, 0.02
# CV AUC (mean, std_err): 0.79, 0.01
# CV Confusion Matrix (mean): [[ 0.58978251  0.41021749]
#  [ 0.18977938  0.81022062]]
# fluctuating_scores
# ANN_Layer2
# CV Acc (mean, std_err): 0.94, 0.01
# CV AUC (mean, std_err): 0.99, 0.00
# CV Confusion Matrix (mean): [[ 0.98019139  0.01980861]
#  [ 0.13342546  0.86657454]]
# steady_scores_easy
# ANN_Layer2
# CV Acc (mean, std_err): 0.99, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.         0.       ]
#  [ 0.0535527  0.9464473]]
# exp_idx: tp: bl, feat: cs+ct
# all
# ANN_Layer2
# CV Acc (mean, std_err): 0.84, 0.01
# CV AUC (mean, std_err): 0.91, 0.01
# CV Confusion Matrix (mean): [[ 0.89468434  0.10531566]
#  [ 0.22768157  0.77231843]]
# steady_scores_tough
# ANN_Layer2
# CV Acc (mean, std_err): 0.68, 0.03
# CV AUC (mean, std_err): 0.67, 0.03
# CV Confusion Matrix (mean): [[ 0.52743677  0.47256323]
#  [ 0.22848516  0.77151484]]
# fluctuating_scores
# ANN_Layer2
# CV Acc (mean, std_err): 0.84, 0.02
# CV AUC (mean, std_err): 0.93, 0.01
# CV Confusion Matrix (mean): [[ 0.95748051  0.04251949]
#  [ 0.2990293   0.7009707 ]]
# steady_scores_easy
# ANN_Layer2
# CV Acc (mean, std_err): 0.95, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99761905  0.00238095]
#  [ 0.14493807  0.85506193]]
# exp_idx: tp: bl+1, feat: ct
# all
# ANN_Layer2
# CV Acc (mean, std_err): 0.75, 0.01
# CV AUC (mean, std_err): 0.83, 0.02
# CV Confusion Matrix (mean): [[ 0.83248107  0.16751893]
#  [ 0.33537032  0.66462968]]
# steady_scores_tough
# ANN_Layer2
# CV Acc (mean, std_err): 0.67, 0.03
# CV AUC (mean, std_err): 0.72, 0.02
# CV Confusion Matrix (mean): [[ 0.55018162  0.44981838]
#  [ 0.19372861  0.80627139]]
# fluctuating_scores
# ANN_Layer2
# CV Acc (mean, std_err): 0.76, 0.03
# CV AUC (mean, std_err): 0.84, 0.03
# CV Confusion Matrix (mean): [[ 0.87465588  0.12534412]
#  [ 0.3887605   0.6112395 ]]
# steady_scores_easy
# ANN_Layer2
# CV Acc (mean, std_err): 0.81, 0.01
# CV AUC (mean, std_err): 0.92, 0.01
# CV Confusion Matrix (mean): [[ 0.96411546  0.03588454]
#  [ 0.43304465  0.56695535]]
# exp_idx: tp: bl, feat: ct
# all
# ANN_Layer2
# CV Acc (mean, std_err): 0.75, 0.02
# CV AUC (mean, std_err): 0.81, 0.01
# CV Confusion Matrix (mean): [[ 0.82758098  0.17241902]
#  [ 0.33342664  0.66657336]]
# steady_scores_tough
# ANN_Layer2
# CV Acc (mean, std_err): 0.70, 0.03
# CV AUC (mean, std_err): 0.72, 0.03
# CV Confusion Matrix (mean): [[ 0.54104838  0.45895162]
#  [ 0.17616362  0.82383638]]
# fluctuating_scores
# ANN_Layer2
# CV Acc (mean, std_err): 0.74, 0.03
# CV AUC (mean, std_err): 0.81, 0.03
# CV Confusion Matrix (mean): [[ 0.85296477  0.14703523]
#  [ 0.39985315  0.60014685]]
# steady_scores_easy
# ANN_Layer2
# CV Acc (mean, std_err): 0.80, 0.02
# CV AUC (mean, std_err): 0.90, 0.02
# CV Confusion Matrix (mean): [[ 0.95826615  0.04173385]
#  [ 0.4464637   0.5535363 ]]
# exp_idx: tp: bl, feat: cs
# all
# ANN_Layer2
# CV Acc (mean, std_err): 0.84, 0.01
# CV AUC (mean, std_err): 0.91, 0.01
# CV Confusion Matrix (mean): [[ 0.87926077  0.12073923]
#  [ 0.20270928  0.79729072]]
# steady_scores_tough
# ANN_Layer2
# CV Acc (mean, std_err): 0.62, 0.03
# CV AUC (mean, std_err): 0.61, 0.02
# CV Confusion Matrix (mean): [[ 0.44318182  0.55681818]
#  [ 0.26812205  0.73187795]]
# fluctuating_scores
# ANN_Layer2
# CV Acc (mean, std_err): 0.85, 0.02
# CV AUC (mean, std_err): 0.94, 0.02
# CV Confusion Matrix (mean): [[ 0.95819866  0.04180134]
#  [ 0.28225275  0.71774725]]
# steady_scores_easy
# ANN_Layer2
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.  0.]
#  [ 0.  1.]]
# exp_idx: tp: bl+1, feat: cs
# all
# ANN_Layer2
# CV Acc (mean, std_err): 0.91, 0.01
# CV AUC (mean, std_err): 0.96, 0.01
# CV Confusion Matrix (mean): [[ 0.90740843  0.09259157]
#  [ 0.09155487  0.90844513]]
# steady_scores_tough
# ANN_Layer2
# CV Acc (mean, std_err): 0.72, 0.03
# CV AUC (mean, std_err): 0.77, 0.03
# CV Confusion Matrix (mean): [[ 0.56330128  0.43669872]
#  [ 0.15754504  0.84245496]]
# fluctuating_scores
# ANN_Layer2
# CV Acc (mean, std_err): 0.97, 0.01
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 0.99565217  0.00434783]
#  [ 0.08300117  0.91699883]]
# steady_scores_easy
# ANN_Layer2
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.  0.]
#  [ 0.  1.]]
# exp_idx: tp: bl+1, feat: ct
# /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/TF_perf/benchmarks/Exp_502_ALL_ADNI_traj_MMSE_tp_var_tp_feat_CT_Siamese_Layer2_dist_mod_slim_df_perf.pkl
# all
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 0.77, 0.01
# CV AUC (mean, std_err): 0.83, 0.01
# CV Confusion Matrix (mean): [[ 0.7945298   0.2054702 ]
#  [ 0.27494852  0.72505148]]
# steady_scores_tough
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 0.60, 0.02
# CV AUC (mean, std_err): 0.68, 0.03
# CV Confusion Matrix (mean): [[ 0.4363429   0.5636571 ]
#  [ 0.20139716  0.79860284]]
# fluctuating_scores
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 0.82, 0.02
# CV AUC (mean, std_err): 0.86, 0.03
# CV Confusion Matrix (mean): [[ 0.86605813  0.13394187]
#  [ 0.2750777   0.7249223 ]]
# steady_scores_easy
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 0.85, 0.02
# CV AUC (mean, std_err): 0.93, 0.01
# CV Confusion Matrix (mean): [[ 0.94545716  0.05454284]
#  [ 0.34741794  0.65258206]]
# exp_idx: tp: bl+1, feat: cs+ct
# /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/TF_perf/benchmarks/Exp_502_ALL_ADNI_traj_MMSE_tp_var_tp_feat_CS_CT_aux_Siamese_Layer2_dist_mod_slim_df_perf_tanh.pkl
# all
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 0.91, 0.01
# CV AUC (mean, std_err): 0.95, 0.01
# CV Confusion Matrix (mean): [[ 0.8898907   0.1101093 ]
#  [ 0.06267916  0.93732084]]
# steady_scores_tough
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 0.72, 0.02
# CV AUC (mean, std_err): 0.74, 0.02
# CV Confusion Matrix (mean): [[ 0.54609758  0.45390242]
#  [ 0.09283778  0.90716222]]
# fluctuating_scores
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 0.97, 0.01
# CV AUC (mean, std_err): 0.99, 0.00
# CV Confusion Matrix (mean): [[ 0.98485672  0.01514328]
#  [ 0.05227273  0.94772727]]
# steady_scores_easy
# Siamese_Layer2_dist_mod_slim
# CV Acc (mean, std_err): 1.00, 0.00
# CV AUC (mean, std_err): 1.00, 0.00
# CV Confusion Matrix (mean): [[ 1.          0.        ]
#  [ 0.01394231  0.98605769]]

# %%
plt.rcParams['figure.figsize'] = (20, 20)
sns.set(font_scale=2.5)
flatui = ["#9b59b6", "#3498db", "#e74c3c", "#2ecc71","#95a5a6","#34495e"]
hue_order = ['tp: bl, feat: cs','tp: bl, feat: ct','tp: bl, feat: cs+ct',
             'tp: bl+1, feat: cs','tp: bl+1, feat: ct','tp: bl+1, feat: cs+ct']
with sns.axes_style("whitegrid"):
    g = sns.factorplot(y='AUC',x='model',col='subset',hue='Input', 
                       data=CV_summary_df,                       
                       hue_order=hue_order,kind='bar',palette=flatui,size=10, col_wrap=2)
    g.set_xticklabels(rotation=30)

# %%
def get_CS_Traj_count(df,cs,max_score,null_offset):
    # generate a matrix of counts of stable vs declining subjects per CS_pair(BL,TP)
    # null_offset get's rid of scores which are non-existent in the dataset
    S = np.zeros((max_score+1 - null_offset, max_score+1 - null_offset))
    D = np.zeros((max_score+1 - null_offset, max_score+1 - null_offset))
    for sub in df['PTID'].values:
        cs_bl = int(df[df['PTID']==sub]['{}_bl'.format(cs)].values) - null_offset
        cs_tp = int(df[df['PTID']==sub]['{}_var_tp'.format(cs)].values) - null_offset
        if df[df['PTID']==sub]['act_label'].any()==0:
            S[cs_bl,cs_tp] += 1
        else:
            D[cs_bl,cs_tp] += 1        
            
    return S.astype(float),D.astype(float)

# %%
cs = 'MMSE'
max_score = 30
null_offset = 15
SD_df = df_perf_dx_merge[['PTID','ORIGPROT','{}_bl'.format(clinical_scale),'{}_var_tp'.format(clinical_scale),'act_label']]
S,D = get_CS_Traj_count(SD_df,cs,max_score,null_offset)

plot_metric = (D-S)/(D+S)

#print(plot_metric)
plot_metric[plot_metric >= 0.34] = 0
plot_metric[plot_metric <= -0.32] = 0

fig, ax = plt.subplots(figsize=(20,10))         # Sample figsize in inches
sns.set(font_scale=1)
h1 = sns.heatmap(plot_metric, annot=True,fmt='f')
plt.xlabel('Timepoint 1')
plt.ylabel('Baseline')
# Out:
# /mnt/tigrlab/projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in divide
#   import sys
# /mnt/tigrlab/projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in greater_equal
#   # Remove the CWD from sys.path while we load stuff.
# /mnt/tigrlab/projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in less_equal
#   # This is added back by InteractiveShellApp.init_path()

# %%
# all CS timpoints:
test_df = pd.read_pickle(baseline_dir + 'ADNI_MMSE_scores_trajectory.pkl') 
FP_df = df_perf_dx_merge[(df_perf_dx_merge['act_label']==0)&(df_perf_dx_merge['pred_label']==1)]
FN_df = df_perf_dx_merge[(df_perf_dx_merge['act_label']==1)&(df_perf_dx_merge['pred_label']==0)]
cs_cols = list(test_df.columns[pd.Series(test_df.columns).str.contains('MMSE_')])
print('# of FPs: {}, FNs: {}'.format(len(FP_df),len(FN_df)))
FP_df = pd.merge(test_df[['PTID','APOE4']+cs_cols],FP_df[['PTID','distance','d_mod','pred_wt','pred_prob']],on='PTID',how='inner')
FN_df = pd.merge(test_df[['PTID','APOE4']+cs_cols],FN_df[['PTID','distance','d_mod','pred_wt','pred_prob']],on='PTID',how='inner')

FP_df
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-86f22b70f65c> in <module>()
#       1 # all CS timpoints:
# ----> 2 test_df = pd.read_pickle(baseline_dir + 'ADNI_ADAS13_scores_trajectory.pkl')
#       3 FP_df = df_perf_dx_merge[(df_perf_dx_merge['act_label']==0)&(df_perf_dx_merge['pred_label']==1)]
#       4 FN_df = df_perf_dx_merge[(df_perf_dx_merge['act_label']==1)&(df_perf_dx_merge['pred_label']==0)]
#       5 cs_cols = list(test_df.columns[pd.Series(test_df.columns).str.contains('ADAS_')])
#
# /projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      63
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#      67         if PY3:
#
# /projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      59             # compat pickle
#      60             except:
# ---> 61                 with open(path, 'rb') as fh:
#      62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#
# IOError: [Errno 2] No such file or directory: '/projects/nbhagwat/Traj_prediction/ADNI/exp_setup/ADNI_ADAS13_scores_trajectory.pkl'

# %%
plt.style.use('seaborn-white')
plt.rcParams['figure.figsize'] = (20, 10)
plt.subplot(1,2,1)
plt.plot(FP_df[cs_cols].values.T,'-d');
plt.title('False Positives (predict=decline)')
plt.axis([0,10,0,30])
plt.subplot(1,2,2)
plt.plot(FN_df[cs_cols].values.T,'-o');
plt.title('False Negatives (predict=stable)')
plt.axis([0,10,0,30])

# [ 28.4  28.6  29.   28.9  29.   28.8  28.7  28.3  27.6]
# [ 26.8  25.7  25.5  25.   24.3  23.   21.9  20.5  18.2]
# Out:
# [0, 10, 0, 30]

# %%
sns.set(font_scale=2.5)
ct_cols = list(in_data.columns[pd.Series(in_data.columns).str.contains('CT_rate')])
cs_cols = ['MMSE_bl','MMSE_var_tp','AGE','APOE4']
print_demo_table = False


#True negatives
ptid_list = list(df_perf_dx_merge[(df_perf_dx_merge['act_label']==0)&(df_perf_dx_merge['pred_label']==0)]['PTID'].values)
print('True negatives')
print(np.mean(df_perf_dx_merge[df_perf_dx_merge['PTID'].isin(ptid_list)]['distance'].values))
print(np.mean(df[df['PTID'].isin(ptid_list)][cs_cols].values,axis=0))
plot_df = get_sub_info(ptid_list,df,cs_cols,ct_cols,print_demo_table)
with sns.axes_style("whitegrid"):
    g = sns.factorplot(data=plot_df,kind='bar',size=10,aspect=3)
    g.set_xticklabels(rotation=90)
    g.set(ylim=(-0.015,0.015))
    
    
#True positives
ptid_list = list(df_perf_dx_merge[(df_perf_dx_merge['act_label']==1)&(df_perf_dx_merge['pred_label']==1)]['PTID'].values)
print('True positives')
print(np.mean(df_perf_dx_merge[df_perf_dx_merge['PTID'].isin(ptid_list)]['distance'].values))
print(np.mean(df[df['PTID'].isin(ptid_list)][cs_cols].values,axis=0))
plot_df = get_sub_info(ptid_list,df,cs_cols,ct_cols,print_demo_table)
with sns.axes_style("whitegrid"):
    g = sns.factorplot(data=plot_df,kind='bar',size=10,aspect=3)
    g.set_xticklabels(rotation=90)
    g.set(ylim=(-0.015,0.015))
    
#False positives
ptid_list = list(df_perf_dx_merge[(df_perf_dx_merge['act_label']==0)&(df_perf_dx_merge['pred_label']==1)]['PTID'].values)
print('False positives')
print(np.mean(df_perf_dx_merge[df_perf_dx_merge['PTID'].isin(ptid_list)]['distance'].values))
print(np.mean(df[df['PTID'].isin(ptid_list)][cs_cols].values,axis=0))
plot_df = get_sub_info(ptid_list,df,cs_cols,ct_cols,print_demo_table)
with sns.axes_style("whitegrid"):
    g = sns.factorplot(data=plot_df,kind='bar',size=10,aspect=3)
    g.set_xticklabels(rotation=90)
    g.set(ylim=(-0.015,0.015))

#False negatives
ptid_list = list(df_perf_dx_merge[(df_perf_dx_merge['act_label']==1)&(df_perf_dx_merge['pred_label']==0)]['PTID'].values)
print('False negatives')
print(np.mean(df_perf_dx_merge[df_perf_dx_merge['PTID'].isin(ptid_list)]['distance'].values))
print(np.mean(df[df['PTID'].isin(ptid_list)][cs_cols].values,axis=0))
plot_df = get_sub_info(ptid_list,df,cs_cols,ct_cols,print_demo_table)
with sns.axes_style("whitegrid"):
    g = sns.factorplot(data=plot_df,kind='bar',size=10,aspect=3)
    g.set_xticklabels(rotation=90)
    g.set(ylim=(-0.015,0.015))
# Out:
# True negatives
# 0.661123
# [ 28.86936236  28.9222395   72.79642302   0.36702955]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-a4065947b2b0> in <module>()
#      12 plot_df = get_sub_info(ptid_list,df,cs_cols,ct_cols,print_demo_table)
#      13 with sns.axes_style("whitegrid"):
# ---> 14     g = sns.factorplot(data=plot_df,kind='bar',size=10,aspect=3)
#      15     g.set_xticklabels(rotation=90)
#      16     g.set(ylim=(-0.015,0.015))
#
# /projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/seaborn/categorical.pyc in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3397     # so we need to define ``palette`` to get default behavior for the
#    3398     # categorical functions
# -> 3399     p.establish_colors(color, palette, 1)
#    3400     if kind != "point" or hue is not None:
#    3401         palette = p.colors
#
# /projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/seaborn/categorical.pyc in establish_colors(self, color, palette, saturation)
#     304         # Determine the gray color to use for the lines framing the plot
#     305         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 306         l = min(light_vals) * .6
#     307         gray = mpl.colors.rgb2hex((l, l, l))
#     308
#
# ValueError: min() arg is an empty sequence

# %%
with sns.axes_style("whitegrid"):
    g = sns.factorplot(y='distance',x='APOE4', hue='DX_bl', kind='bar',
                       data=df_perf_dx_merge,palette=flatui,size=10)

# %%
plot_df = tmp_df[tmp_df['MMSE_bl_quantile'].isin(['T0_low','T1_high'])]
p1 = np.vstack((plot_df['pred_prob'].values))[:,1]
match = plot_df['pred_label'].values - plot_df['act_label'].values

plot_df['p1'] = np.array(10*p1).astype(int)
plot_df['delta_cs'] = plot_df['MMSE_bl'].values - plot_df['MMSE_var_tp'].values
plot_df['match'] = match

col_order = ['tp: bl, feat: cs','tp: bl, feat: cs+ct','tp: bl+1, feat: cs','tp: bl+1, feat: cs+ct']
with sns.axes_style("whitegrid"):
#     g = sns.lmplot(y='p1',x='MMSE_bl',col='Input',col_order=col_order, hue='act_label',x_jitter=True,
#                    data=plot_df,palette=flatui,size=10, col_wrap=2)
    g = sns.lmplot(y='delta_cs',x='distance',col='Input', hue='match',x_jitter=False,fit_reg=False,
                   y_jitter=True, data=plot_df,palette=flatui,size=10, col_wrap=2,)
# Out:
# /mnt/tigrlab/projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /mnt/tigrlab/projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /mnt/tigrlab/projects/nbhagwat/ADNI_prediction/code/conda_envs/AD_traj_hopper/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
for q in quants:
#or q in [0,1]:
    df_quant = df[df['MMSE_bl_quantile']==q]
    #df_quant = df[df['traj']==q]
    print 'quant {}, q_count:{}, mmse_bl:{},{},mmse_tp:{},{}, age: {}, e4:{},{},{}'.format(q, len(df_quant),
                                                                                 np.mean(df_quant['MMSE_bl']),
                                                                                 np.std(df_quant['MMSE_bl']),
                                                                                 np.mean(df_quant['MMSE_var_tp']),
                                                                                 np.std(df_quant['MMSE_var_tp']),
                                                                                 np.mean(df_quant['AGE']),
                                                                                 len(df_quant[df_quant['APOE4']==0]),
                                                                                 len(df_quant[df_quant['APOE4']==1]),
                                                                                 len(df_quant[df_quant['APOE4']==2]))
# Out:
# quant T0_low, q_count:103, mmse_bl:27.2524271845,1.07683865431,mmse_tp:28.2912621359,1.43892535387, age: 72.6932038835, e4:63,33,7
# quant T0_high, q_count:256, mmse_bl:29.51171875,0.499862652034,mmse_tp:28.90234375,1.26947115242, age: 71.1859375, e4:168,78,10
# quant T1_low, q_count:109, mmse_bl:23.1009174312,1.68612771795,mmse_tp:21.4220183486,3.93594020331, age: 74.3981651376, e4:31,51,27
# quant T1_high, q_count:98, mmse_bl:27.306122449,1.31248450537,mmse_tp:25.4285714286,2.5674572508, age: 73.9285714286, e4:35,45,18

# %%
#ROC curves
model_list = ['LR_L1','SVC','RFC']
save_figure = False
save_path = baseline_dir + 'Figures/{}'.format('test_ROC.png')

df_subx_perf_paths = {'tp: bl, feat: cs':'df_perf_dict_Exp_101_{}_traj_{}_tp_bl_feat_CS_df.pkl'.format(cohort,clinical_scale),
                      'tp: bl, feat: cs+ct':'df_perf_dict_Exp_101_{}_traj_{}_tp_bl_feat_CS_CT_df.pkl'.format(cohort,clinical_scale),
                      'tp: bl+1, feat: cs':'df_perf_dict_Exp_102_{}_traj_{}_tp_var_tp_feat_CS_df.pkl'.format(cohort,clinical_scale),
                      'tp: bl+1, feat: cs+ct':'df_perf_dict_Exp_102_{}_traj_{}_tp_var_tp_feat_CS_CT_df.pkl'.format(cohort,clinical_scale)}
    
plot_luck = False    
for exp_idx in df_subx_perf_paths:
    print 'exp_idx: ' + exp_idx
    perf_df_path = baseline_dir + 'perf_stats/{}'.format(df_subx_perf_paths[exp_idx])                
    df_perf_concat = pickle.load( open(perf_df_path, "rb" ) )    
    df_perf_dx_merge = pd.merge(df_perf_concat,df[['PTID','DX_bl','MMSE_bl_quantile']],on='PTID',how='inner')
    
    #Plot ROC
    plotROC(df_perf_dx_merge[df_perf_dx_merge['MMSE_bl_quantile'].isin(quant_subset_dict['quant_list_med'])], model_list, exp_idx, plot_luck, save_figure, save_path)

model_list = ['Siamese_Layer2_slim']
df_subx_perf_paths = {'tp: bl+1, feat: cs+ct':'Exp_102_{}_traj_{}_tp_var_tp_feat_CS_CT_Siamese_Layer2_slim_df_perf.pkl'.format(cohort,clinical_scale),
                     'tp: bl+1, feat: ct':'Exp_102_{}_traj_{}_tp_var_tp_feat_CT_Siamese_Layer2_slim_df_perf.pkl'.format(cohort,clinical_scale),
                     'tp: bl+1, feat: cs+ct_aux':'Exp_102_{}_traj_{}_tp_var_tp_feat_CS_CT_aux_Siamese_Layer2_slim_df_perf.pkl'.format(cohort,clinical_scale)}


for e, exp_idx in enumerate(df_subx_perf_paths):
    print 'exp_idx: ' + exp_idx
    perf_df_path = baseline_dir + 'TF_perf/benchmarks/{}'.format(df_subx_perf_paths[exp_idx])                
    df_perf_concat = pickle.load( open(perf_df_path, "rb" ) )    
    df_perf_dx_merge = pd.merge(df_perf_concat,df[['PTID','DX_bl','MMSE_bl_quantile']],on='PTID',how='inner')
    
    if e == len(df_subx_perf_paths)-1:
        plot_luck = True
        
    #Plot ROC
    plotROC(df_perf_dx_merge[df_perf_dx_merge['MMSE_bl_quantile'].isin(quant_subset_dict['quant_list_med'])], model_list, exp_idx, plot_luck, save_figure, save_path)
# Out:
# exp_idx: tp: bl+1, feat: cs+ct
# saving fig at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/Figures/test_ROC.png
# exp_idx: tp: bl, feat: cs
# saving fig at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/Figures/test_ROC.png
# exp_idx: tp: bl, feat: cs+ct
# saving fig at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/Figures/test_ROC.png
# exp_idx: tp: bl+1, feat: cs
# saving fig at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/Figures/test_ROC.png
# exp_idx: tp: bl+1, feat: ct
# saving fig at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/Figures/test_ROC.png
# exp_idx: tp: bl+1, feat: cs+ct
# saving fig at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/Figures/test_ROC.png
# exp_idx: tp: bl+1, feat: cs+ct_aux
# saving fig at: /projects/nbhagwat/Traj_prediction/ADNI/exp_setup/Figures/test_ROC.png

# %%
tmp = df_perf_dx_merge[df_perf_dx_merge['MMSE_bl_quantile'].isin(quant_list_med)]
# for kf in np.arange(1,11,1):
#     print np.vstack((tmp[tmp['kf']==kf]['pred_prob'].values))[:,1]
tmp
# Out:
#            PTID       model  kf  act_label  pred_label             pred_prob  \
# 0    002_S_4171  ANN_Layer2   1          1           0  [0.803836, 0.196164]
# 1    002_S_4213  ANN_Layer2   1          0           0  [0.704377, 0.295623]
# 3    002_S_4225  ANN_Layer2   1          0           0  [0.589456, 0.410544]
# 7    002_S_4262  ANN_Layer2   1          1           0  [0.852403, 0.147597]
# 8    002_S_4270  ANN_Layer2   1          0           0  [0.512546, 0.487454]
# 9    002_S_4447  ANN_Layer2   1          0           1  [0.244905, 0.755095]
# 10   002_S_4473  ANN_Layer2   1          0           1  [0.179699, 0.820301]
# 11   002_S_4521  ANN_Layer2   1          1           1  [0.217852, 0.782148]
# 13   002_S_4746  ANN_Layer2   1          0           0  [0.788576, 0.211424]
# 16   002_S_5178  ANN_Layer2   1          0           1  [0.446104, 0.553896]
# 19   003_S_4081  ANN_Layer2   1          0           0    [0.54819, 0.45181]
# 26   003_S_4555  ANN_Layer2   1          0           0  [0.621009, 0.378991]
# 28   003_S_4872  ANN_Layer2   1          0           1  [0.152964, 0.847036]
# 35   003_S_5209  ANN_Layer2   1          1           0  [0.841618, 0.158382]
# 37   005_S_4185  ANN_Layer2   1          0           0  [0.677232, 0.322768]
# 42   006_S_4150  ANN_Layer2   1          0           0  [0.757981, 0.242019]
# 47   006_S_4363  ANN_Layer2   1          1           1  [0.176237, 0.823763]
# 48   006_S_4449  ANN_Layer2   1          0           0  [0.817831, 0.182169]
# 49   006_S_4485  ANN_Layer2   1          0           1  [0.176407, 0.823593]
# 50   006_S_4515  ANN_Layer2   1          1           1  [0.139364, 0.860636]
# 51   006_S_4679  ANN_Layer2   1          0           0  [0.598246, 0.401754]
# 54   006_S_4960  ANN_Layer2   1          0           1    [0.15385, 0.84615]
# 56   007_S_4272  ANN_Layer2   1          1           0  [0.791429, 0.208571]
# 58   007_S_4467  ANN_Layer2   1          1           1  [0.248333, 0.751667]
# 60   007_S_4516  ANN_Layer2   1          0           0  [0.786606, 0.213394]
# 68   009_S_4324  ANN_Layer2   1          1           1  [0.292799, 0.707201]
# 69   009_S_4337  ANN_Layer2   1          1           1  [0.177989, 0.822011]
# 72   009_S_4530  ANN_Layer2   2          1           0  [0.837169, 0.162831]
# 77   009_S_4903  ANN_Layer2   2          0           1  [0.481665, 0.518335]
# 78   009_S_4958  ANN_Layer2   2          0           0  [0.589747, 0.410253]
# ..          ...         ...  ..        ...         ...                   ...
# 611  135_S_4356  ANN_Layer2   9          0           0  [0.774691, 0.225309]
# 616  135_S_4722  ANN_Layer2   9          0           0  [0.774891, 0.225109]
# 621  130_S_5231  ANN_Layer2  10          1           1  [0.176111, 0.823889]
# 623  135_S_4406  ANN_Layer2  10          1           0  [0.836145, 0.163855]
# 626  135_S_4689  ANN_Layer2  10          1           0  [0.718739, 0.281261]
# 627  135_S_4863  ANN_Layer2  10          1           1  [0.141083, 0.858917]
# 631  136_S_4189  ANN_Layer2  10          1           0  [0.541658, 0.458342]
# 635  137_S_4299  ANN_Layer2  10          0           1  [0.144804, 0.855196]
# 640  137_S_4482  ANN_Layer2  10          0           0  [0.708912, 0.291088]
# 642  137_S_4536  ANN_Layer2  10          0           0    [0.69328, 0.30672]
# 644  137_S_4596  ANN_Layer2  10          1           0  [0.855962, 0.144038]
# 646  137_S_4631  ANN_Layer2  10          0           0  [0.794175, 0.205825]
# 652  137_S_4816  ANN_Layer2  10          1           0  [0.682152, 0.317848]
# 653  137_S_4852  ANN_Layer2  10          1           1  [0.144636, 0.855364]
# 654  137_S_4862  ANN_Layer2  10          1           0  [0.842584, 0.157416]
# 655  141_S_4053  ANN_Layer2  10          1           0  [0.676813, 0.323187]
# 656  141_S_4160  ANN_Layer2  10          0           1  [0.146257, 0.853743]
# 658  141_S_4423  ANN_Layer2  10          1           0  [0.700131, 0.299869]
# 659  141_S_4426  ANN_Layer2  10          0           0  [0.708912, 0.291088]
# 661  141_S_4456  ANN_Layer2  10          0           1  [0.165906, 0.834094]
# 662  141_S_4711  ANN_Layer2  10          0           1  [0.341679, 0.658321]
# 665  153_S_4077  ANN_Layer2  10          0           0    [0.74271, 0.25729]
# 667  153_S_4133  ANN_Layer2  10          0           1  [0.183022, 0.816978]
# 673  153_S_4621  ANN_Layer2  10          0           0  [0.792698, 0.207302]
# 674  153_S_4838  ANN_Layer2  10          0           1  [0.171381, 0.828619]
# 676  153_S_5267  ANN_Layer2  10          0           0  [0.720828, 0.279172]
# 678  941_S_4100  ANN_Layer2  10          0           0  [0.678983, 0.321017]
# 681  941_S_4292  ANN_Layer2  10          0           0  [0.788089, 0.211911]
# 685  941_S_4420  ANN_Layer2  10          0           1  [0.235394, 0.764606]
# 687  941_S_5124  ANN_Layer2  10          1           1  [0.168114, 0.831886]
#
#                                          test_embed_l1  \
# 0    [0.448055, 0.299813, -0.0114321, -0.0341219, 0...
# 1    [0.432564, 0.176169, -0.295835, 0.605597, 0.75...
# 3    [-0.192825, 0.107481, -0.0733429, -0.474262, -...
# 7    [0.620701, 0.574882, -0.471482, 0.119195, 0.78...
# 8    [-0.202916, 0.0361315, -0.229711, -0.1128, -0....
# 9    [-0.414792, -0.247585, 0.373889, -0.525468, -0...
# 10   [-0.428206, -0.348979, 0.142807, 0.0409198, -0...
# 11   [-0.419407, -0.283058, 0.298263, -0.353895, -0...
# 13   [0.444834, 0.274602, -0.0727374, 0.119355, 0.6...
# 16   [0.228468, -0.0757032, 0.380267, 0.0344857, 0....
# 19   [-0.198842, 0.0650606, -0.167446, -0.269109, -...
# 26   [-0.183989, 0.168855, 0.0663594, -0.699578, -0...
# 28   [-0.601247, -0.581998, 0.631139, -0.346242, -0...
# 35   [0.616147, 0.540177, -0.554324, 0.381839, 0.83...
# 37   [0.428195, 0.140453, -0.36865, 0.71986, 0.790552]
# 42   [0.439982, 0.236078, -0.163535, 0.33728, 0.667...
# 47   [-0.0298459, -0.49904, 0.54948, 0.530612, 0.19...
# 48   [0.452509, 0.334138, 0.0737575, -0.243141, 0.4...
# 49   [-0.0293994, -0.496743, 0.554227, 0.518202, 0....
# 50   [-0.609879, -0.640253, 0.489282, 0.159556, -0....
# 51   [-0.191103, 0.119536, -0.0461382, -0.525586, -...
# 54   [-0.729047, -0.729186, 0.891986, -0.755571, -0...
# 56   [0.445372, 0.278831, -0.0625455, 0.0939717, 0....
# 58   [-0.802391, -0.346211, 0.492296, -0.919747, -0...
# 60   [0.444476, 0.271777, -0.0795238, 0.136193, 0.6...
# 68   [-0.406059, -0.179135, 0.503024, -0.75571, -0....
# 69   [-0.0264967, -0.481648, 0.58421, 0.432211, 0.1...
# 72   [0.647618, -0.636712, -0.783489, 0.272848, 0.3...
# 77   [-0.043814, 0.171596, -0.231684, 0.588101, -0....
# 78   [-0.403846, -0.351126, -0.170219, -0.0904129, ...
# ..                                                 ...
# 611  [-0.541767, 0.201701, -0.311083, 0.281333, -0....
# 616  [-0.545881, 0.207541, -0.315724, 0.28495, -0.8...
# 621  [-0.0729135, 0.393648, -0.307894, -0.734607, 0...
# 623  [-0.0126135, -0.396206, 0.568292, 0.12222, -0....
# 626  [0.637723, -0.282073, 0.0388439, 0.977623, -0....
# 627  [0.850396, 0.523592, -0.693868, 0.954059, -0.0...
# 631  [0.377178, -0.0730518, 0.0264875, 0.708837, -0...
# 635  [0.351662, 0.619322, -0.524797, -0.619386, 0.7...
# 640  [-0.0474583, -0.140724, 0.311424, -0.244156, -...
# 642  [0.0298654, -0.135882, 0.319948, -0.152485, -0...
# 644  [-0.899874, -0.471667, 0.435348, -0.932618, -0...
# 646  [-0.715588, -0.193486, 0.214597, -0.861658, 0....
# 652  [0.85182, -0.251954, 0.100732, 0.993571, -0.82...
# 653  [0.540936, 0.492742, -0.732995, 0.789527, 0.11...
# 654  [-0.187221, -0.405673, 0.553461, -0.095175, -0...
# 655  [0.881916, -0.244677, 0.115434, 0.995234, -0.8...
# 656  [0.0688097, 0.607448, -0.550747, -0.797747, 0....
# 658  [-0.00328353, -0.137958, 0.316301, -0.192194, ...
# 659  [-0.0474583, -0.140724, 0.311424, -0.244156, -...
# 661  [0.283692, 0.413128, -0.26696, -0.452963, 0.60...
# 662  [-0.147603, 0.130828, -0.00886699, -0.606315, ...
# 665  [-0.24157, -0.153141, 0.289278, -0.457998, 0.0...
# 667  [0.856286, 0.256928, -0.182077, 0.928202, -0.1...
# 673  [-0.693327, -0.190769, 0.219752, -0.846925, 0....
# 674  [0.081512, 0.401957, -0.290657, -0.633745, 0.6...
# 676  [-0.388535, -0.124012, -0.0721075, -0.110687, ...
# 678  [0.0958943, -0.131727, 0.327212, -0.0716987, -...
# 681  [-0.63144, -0.183966, 0.232584, -0.803616, 0.1...
# 685  [0.515161, 0.175575, 0.0788758, 0.181721, 0.25...
# 687  [0.200518, 0.408439, -0.276979, -0.535318, 0.6...
#
#                                          test_embed_l2 DX_bl MMSE_bl_quantile
# 0    [0.375504, 0.558557, 0.239595, -0.303157, 0.34...  LMCI          T1_high
# 1    [-0.0937728, 0.751103, 0.0756637, 0.10407, 0.0...    CN           T0_low
# 3    [0.298663, -0.40956, -0.0233564, -0.23257, 0.3...    CN           T0_low
# 7    [0.515265, 0.818398, 0.236122, -0.375025, 0.66...    CN          T1_high
# 8    [0.0328567, -0.198158, -0.12155, 0.00862132, 0...    CN           T0_low
# 9    [-0.00339499, -0.752175, -0.0704295, -0.036807...  EMCI           T0_low
# 10   [-0.408071, -0.592518, -0.209526, 0.307293, -0...  EMCI           T0_low
# 11   [-0.135212, -0.70906, -0.115846, 0.0774026, -0...  LMCI          T1_high
# 13   [0.272615, 0.611159, 0.203942, -0.21633, 0.284...  LMCI           T0_low
# 16   [-0.00736506, 0.111622, 0.170328, -0.0474945, ...   SMC           T0_low
# 19   [0.150138, -0.289142, -0.081353, -0.0929674, 0...    CN           T0_low
# 26   [0.450233, -0.551865, 0.0556422, -0.402689, 0....    CN           T0_low
# 28   [-0.400998, -0.853772, -0.170804, 0.274685, -0...    CN           T0_low
# 35   [0.35732, 0.847005, 0.185159, -0.252922, 0.570...   SMC          T1_high
# 37   [-0.185232, 0.783141, 0.0357784, 0.199622, 0.0...  EMCI           T0_low
# 42   [0.114193, 0.676924, 0.150983, -0.0837263, 0.1...    CN           T0_low
# 47   [-0.617313, -0.13256, -0.0309264, 0.451484, -0...  LMCI          T1_high
# 48   [0.501271, 0.473064, 0.288097, -0.415316, 0.42...    CN           T0_low
# 49   [-0.611502, -0.141871, -0.0275235, 0.444709, -...    CN           T0_low
# 50   [-0.663224, -0.797272, -0.263087, 0.485381, -0...  LMCI          T1_high
# 51   [0.334357, -0.440558, -0.00729964, -0.269218, ...  EMCI           T0_low
# 54   [-0.293672, -0.919569, -0.159352, 0.246465, -0...  LMCI           T0_low
# 56   [0.290187, 0.602898, 0.209891, -0.23101, 0.295...  EMCI          T1_high
# 58   [0.0478765, -0.892173, -0.200795, -0.0318932, ...  EMCI          T1_high
# 60   [0.260845, 0.616556, 0.199978, -0.206515, 0.27...    CN           T0_low
# 68   [0.182266, -0.809687, 0.0047632, -0.220667, -0...  LMCI          T1_high
# 69   [-0.569463, -0.20181, -0.00517501, 0.39845, -0...    CN          T1_high
# 72   [-0.124587, 0.817413, -0.859418, -0.358034, -0...  EMCI          T1_high
# 77   [-0.0259462, -0.338154, -0.173451, 0.157689, -...  LMCI           T0_low
# 78   [-0.0297436, 0.275369, -0.33352, 0.175091, 0.2...  EMCI           T0_low
# ..                                                 ...   ...              ...
# 611  [-0.0211209, 0.320986, -0.312814, -0.940539, 0...  EMCI           T0_low
# 616  [-0.0177353, 0.319881, -0.315373, -0.942335, 0...  LMCI           T0_low
# 621  [-0.436618, 0.246728, 0.401468, 0.718138, -0.6...    AD          T1_high
# 623  [-0.0618168, -0.506217, 0.051785, -0.534644, 0...  LMCI          T1_high
# 626  [0.416961, -0.124949, -0.462053, -0.485985, 0....  LMCI          T1_high
# 627  [0.366977, 0.689321, -0.560255, 0.648601, -0.8...    AD          T1_high
# 631  [0.285595, 0.0559171, -0.381489, -0.189589, -0...  LMCI          T1_high
# 635  [-0.541614, 0.428607, 0.380906, 0.903071, -0.8...  EMCI           T0_low
# 640  [-0.257898, -0.322223, 0.234469, -0.0671637, 0...    CN           T0_low
# 642  [-0.250666, -0.314025, 0.191905, -0.0359869, 0...  EMCI           T0_low
# 644  [-0.170705, -0.581938, 0.50349, -0.708979, 0.8...  LMCI          T1_high
# 646  [-0.227028, -0.336452, 0.451432, -0.345766, 0....  LMCI           T0_low
# 652  [0.297215, -0.184766, -0.411229, -0.351421, -0...  EMCI          T1_high
# 653  [0.42133, 0.703781, -0.544968, 0.566742, -0.84...  LMCI          T1_high
# 654  [-0.0856585, -0.524528, 0.160082, -0.583185, 0...  LMCI          T1_high
# 655  [0.277715, -0.193168, -0.402373, -0.331823, -0...  LMCI          T1_high
# 656  [-0.486666, 0.449182, 0.421038, 0.863142, -0.8...  EMCI           T0_low
# 658  [-0.253997, -0.31768, 0.210547, -0.0492558, 0....  LMCI          T1_high
# 659  [-0.257898, -0.322223, 0.234469, -0.0671637, 0...  LMCI           T0_low
# 661  [-0.482386, 0.23593, 0.313937, 0.80295, -0.706...  LMCI           T0_low
# 662  [-0.377555, -0.0465897, 0.371374, 0.402443, -0...  LMCI           T0_low
# 665  [-0.267077, -0.337358, 0.326068, -0.148414, 0....  LMCI           T0_low
# 667  [0.161597, 0.356509, -0.456012, 0.472459, -0.6...  EMCI           T0_low
# 673  [-0.23105, -0.337825, 0.448788, -0.337558, 0.5...  EMCI           T0_low
# 674   [-0.466573, 0.235046, 0.3779, 0.760823, -0.6524]  EMCI           T0_low
# 676  [0.269844, 0.000622825, -0.0292899, -0.484793,...   SMC           T0_low
# 678  [-0.243062, -0.306154, 0.15313, -0.0100138, 0....    CN           T0_low
# 681  [-0.241089, -0.340902, 0.439635, -0.313607, 0....    CN           T0_low
# 685  [-0.325197, 0.0289328, 0.00887487, 0.60286, -0...  EMCI           T0_low
# 687  [-0.479563, 0.232904, 0.345869, 0.787429, -0.6...   SMC          T1_high
#
# [237 rows x 10 columns]

# %%
# PCA represenatations
from sklearn.decomposition import PCA

select_tp = 'var_tp'
exp_name = 'Exp_102_ADNI2_traj_MMSE_tp_' + select_tp
exp_setup_path = baseline_dir + 'KFolds/' + exp_name + '_sKF.pkl'
exp_setup = pickle.load( open(exp_setup_path, "rb" ) )
df = exp_setup['df']
kf = exp_setup['sKF']

cs_cols = ['MMSE_bl'] + demo_cols

if select_tp == 'var_tp':
    ct_cols_bl = list(df.columns[pd.Series(df.columns).str.contains('CT_bl')])
    ct_cols_tp_rate = list(df.columns[pd.Series(df.columns).str.contains('CT_rate')])
    ct_cols = ct_cols_bl + ct_cols_tp_rate
else:
    ct_cols = list(df.columns[pd.Series(df.columns).str.contains('CT')])

feat_cols = ct_cols

X_raw = np.array(df[feat_cols])
y = np.array(df['traj'])   

k=1
pca_df = pd.DataFrame()
for train, valid in kf:
    Sub_train = df['PTID'].values[train]
    Sub_valid = df['PTID'].values[valid]
    X_tr = X_raw[train]
    y_tr = y[train]
    X_te = X_raw[valid]
    y_te = y[valid]
   
    scaler = preprocessing.StandardScaler().fit(X_tr)
    X_tr = scaler.transform(X_tr)
    X_te = scaler.transform(X_te)
        
    #fit pca
    pca = PCA(n_components=2)
    pca.fit(X_tr)

    X_tr_pc = pca.transform(X_tr)
    X_te_pc = pca.transform(X_te)
    print 'Fold: {}, Explained_variance: {}'.format(k, pca.explained_variance_ratio_)

    pca_df_train = pd.DataFrame()
    pca_df_test = pd.DataFrame()
    pca_df_train['PTID'] = Sub_train
    pca_df_train['PC_1'] = X_tr_pc[:,0]
    pca_df_train['PC_2'] = X_tr_pc[:,1]
    pca_df_train['labels'] = y_tr
    pca_df_train['subset'] = np.tile('train',len(y_tr))
    pca_df_train['KF'] = np.tile(k,len(y_tr))
    
    pca_df_test['PTID'] = Sub_valid
    pca_df_test['PC_1'] = X_te_pc[:,0]
    pca_df_test['PC_2'] = X_te_pc[:,1]
    pca_df_test['labels'] = y_te
    pca_df_test['subset'] = np.tile('test',len(y_te))
    pca_df_test['KF'] = np.tile(k,len(y_te))
    pca_df_train = pca_df_train.append(pca_df_test)
    pca_df = pca_df.append(pca_df_train)
    
    k+=1
    
pca_df = pd.merge(pca_df,df_perf_dx_merge,on='PTID',how='inner')
# Out:
# Fold: 1, Explained_variance: [ 0.33064553  0.22106818]
# Fold: 2, Explained_variance: [ 0.39670124  0.20320236]
# Fold: 3, Explained_variance: [ 0.40398996  0.19477088]
# Fold: 4, Explained_variance: [ 0.39780966  0.19837158]
# Fold: 5, Explained_variance: [ 0.39773131  0.19890415]
# Fold: 6, Explained_variance: [ 0.4030834   0.19899977]
# Fold: 7, Explained_variance: [ 0.4035353   0.19754868]
# Fold: 8, Explained_variance: [ 0.39315962  0.19925208]
# Fold: 9, Explained_variance: [ 0.40258513  0.19281264]
# Fold: 10, Explained_variance: [ 0.39255648  0.19566555]

# %%
foldx = 5
sns.set(font_scale=1.5)
pca_df_all = pca_df[pca_df['KF']==foldx]
pca_df_adcn = pca_df[(pca_df['KF']==foldx)&(pca_df['DX_bl'].isin(['AD','CN']))]
pca_df_mci = pca_df[(pca_df['KF']==foldx)&(pca_df['DX_bl'].isin(['EMCI','LMCI','SMC']))]

with sns.axes_style("whitegrid"):
    g1 = sns.lmplot('PC_1','PC_2',fit_reg=False,hue='labels',col='subset',data=pca_df_all,markers='x',size=8)
    g2 = sns.lmplot('PC_1','PC_2',fit_reg=False,hue='labels',col='subset',data=pca_df_adcn,markers='d',size=8)
    g3 = sns.lmplot('PC_1','PC_2',fit_reg=False,hue='labels',col='subset',data=pca_df_mci,markers='o',size=8)
    #g1.axes[0,0].set_xlim(-20,50)
    #g1.axes[0,1].set_ylim(-10,10)
    g2.axes[0,0].set_xlim(-20,50)
    g2.axes[0,1].set_ylim(-10,10)
    g3.axes[0,0].set_xlim(-20,50)
    g3.axes[0,1].set_ylim(-10,10)

# %%
CV_summary_df[(CV_summary_df['model']=='ANN_Layer2')&(CV_summary_df['Input']=='tp: bl, feat: cs+ct')]
# Out:
#          model  kf  Accuracy       AUC  \
# 0   ANN_Layer2   1  0.818182  0.833333
# 1   ANN_Layer2   2      0.75   0.84375
# 2   ANN_Layer2   3  0.617647  0.727273
# 3   ANN_Layer2   4  0.837209  0.921429
# 4   ANN_Layer2   5      0.78  0.803571
# 5   ANN_Layer2   6  0.865385  0.926692
# 6   ANN_Layer2   7  0.882353  0.970696
# 7   ANN_Layer2   8  0.833333  0.921212
# 8   ANN_Layer2   9  0.861111  0.911111
# 9   ANN_Layer2  10      0.65  0.689655
# 10  ANN_Layer2   1  0.857143  0.925333
# 11  ANN_Layer2   2  0.797101  0.916667
# 12  ANN_Layer2   3  0.753623  0.862037
# 13  ANN_Layer2   4  0.855072  0.939815
# 14  ANN_Layer2   5  0.811594  0.863889
# 15  ANN_Layer2   6  0.869565  0.949074
# 16  ANN_Layer2   7  0.927536  0.987963
# 17  ANN_Layer2   8  0.869565  0.951852
# 18  ANN_Layer2   9  0.882353  0.972538
# 19  ANN_Layer2  10  0.794118  0.869318
# 20  ANN_Layer2   1  0.891892  0.967262
# 21  ANN_Layer2   2  0.848485  0.964286
# 22  ANN_Layer2   3  0.885714  0.972028
# 23  ANN_Layer2   4  0.884615  0.980392
# 24  ANN_Layer2   5  0.894737  0.955556
# 25  ANN_Layer2   6  0.882353  0.971429
# 26  ANN_Layer2   7  0.971429  0.996212
# 27  ANN_Layer2   8  0.952381         1
# 28  ANN_Layer2   9   0.90625  0.992063
# 29  ANN_Layer2  10         1         1
#
#                                                    CM DX_subset  \
# 0   [[0.909090909091, 0.0909090909091], [0.3636363...   smc+mci
# 1   [[0.826086956522, 0.173913043478], [0.38461538...   smc+mci
# 2    [[0.75, 0.25], [0.571428571429, 0.428571428571]]   smc+mci
# 3    [[0.92, 0.08], [0.277777777778, 0.722222222222]]   smc+mci
# 4   [[0.878787878788, 0.121212121212], [0.41176470...   smc+mci
# 5   [[0.897435897436, 0.102564102564], [0.23076923...   smc+mci
# 6   [[0.904761904762, 0.0952380952381], [0.1538461...   smc+mci
# 7   [[0.903225806452, 0.0967741935484], [0.2941176...   smc+mci
# 8   [[0.931034482759, 0.0689655172414], [0.4285714...   smc+mci
# 9   [[0.826086956522, 0.173913043478], [0.58823529...   smc+mci
# 10  [[0.926829268293, 0.0731707317073], [0.2413793...       all
# 11  [[0.878048780488, 0.121951219512], [0.32142857...       all
# 12  [[0.868421052632, 0.131578947368], [0.38709677...       all
# 13  [[0.926829268293, 0.0731707317073], [0.25, 0.75]]       all
# 14  [[0.880952380952, 0.119047619048], [0.29629629...       all
# 15  [[0.891304347826, 0.108695652174], [0.17391304...       all
# 16  [[0.954545454545, 0.0454545454545], [0.12, 0.88]]       all
# 17  [[0.928571428571, 0.0714285714286], [0.2222222...       all
# 18  [[0.928571428571, 0.0714285714286], [0.1923076...       all
# 19  [[0.894736842105, 0.105263157895], [0.33333333...       all
# 20  [[0.947368421053, 0.0526315789474], [0.1666666...     cn+ad
# 21  [[0.944444444444, 0.0555555555556], [0.2666666...     cn+ad
# 22     [[1.0, 0.0], [0.235294117647, 0.764705882353]]     cn+ad
# 23                     [[0.9375, 0.0625], [0.2, 0.8]]     cn+ad
# 24     [[0.888888888889, 0.111111111111], [0.1, 0.9]]     cn+ad
# 25     [[0.857142857143, 0.142857142857], [0.1, 0.9]]     cn+ad
# 26    [[1.0, 0.0], [0.0833333333333, 0.916666666667]]     cn+ad
# 27                           [[1.0, 0.0], [0.1, 0.9]]     cn+ad
# 28  [[0.923076923077, 0.0769230769231], [0.1052631...     cn+ad
# 29                           [[1.0, 0.0], [0.0, 1.0]]     cn+ad
#
#                   Input
# 0   tp: bl, feat: cs+ct
# 1   tp: bl, feat: cs+ct
# 2   tp: bl, feat: cs+ct
# 3   tp: bl, feat: cs+ct
# 4   tp: bl, feat: cs+ct
# 5   tp: bl, feat: cs+ct
# 6   tp: bl, feat: cs+ct
# 7   tp: bl, feat: cs+ct
# 8   tp: bl, feat: cs+ct
# 9   tp: bl, feat: cs+ct
# 10  tp: bl, feat: cs+ct
# 11  tp: bl, feat: cs+ct
# 12  tp: bl, feat: cs+ct
# 13  tp: bl, feat: cs+ct
# 14  tp: bl, feat: cs+ct
# 15  tp: bl, feat: cs+ct
# 16  tp: bl, feat: cs+ct
# 17  tp: bl, feat: cs+ct
# 18  tp: bl, feat: cs+ct
# 19  tp: bl, feat: cs+ct
# 20  tp: bl, feat: cs+ct
# 21  tp: bl, feat: cs+ct
# 22  tp: bl, feat: cs+ct
# 23  tp: bl, feat: cs+ct
# 24  tp: bl, feat: cs+ct
# 25  tp: bl, feat: cs+ct
# 26  tp: bl, feat: cs+ct
# 27  tp: bl, feat: cs+ct
# 28  tp: bl, feat: cs+ct
# 29  tp: bl, feat: cs+ct

# %%
df_perf_concat[df_perf_concat['model']==model_choice]
# Out:
# Empty DataFrame
# Columns: [PTID, model, kf, act_label, pred_label, pred_prob, test_embed_l1, test_embed_l2]
# Index: []
